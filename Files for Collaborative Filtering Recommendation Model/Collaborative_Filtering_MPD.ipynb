# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruby-L-i-n/CSDS234_FinalProject/blob/main/Files%20for%20Collaborative%20Filtering%20Recommendation%20Model/Collaborative_Filtering_MPD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Imported APIs
import numpy as np
import pandas as pd
import heapq
import random
import json
import matplotlib.pyplot as pyplot
from scipy.sparse import csr_matrix
from sklearn.model_selection import train_test_split

import seaborn as sns
sns.set(style='whitegrid')
pd.set_option('display.width', 1500)
pd.set_option('display.max_columns', 100)

# %%
#mount to drive for datasets
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Training Data

# %% [markdown]
# ## Pre-Processing and Formatting JSON Files

# %%
#Here we are only using playlists from the first file of playlists because of hardware limitations
np.random.seed(seed = 19) #a random seed to ensure calculation is the same across methods. if you want to generate a different set of random numbers, enter a new seed

# The variables below are required for random selection of playlists
# (each JSON file stores 1000 playlists so if you wanted 2500 playlists from 3000 you could use these variables)
numbers = np.arange(0,1000,1) #a range of numbers from 1 to 1000
sample = np.random.choice(numbers, size=1000, replace=False) #an array storing the pids of the 800 random playlists

# %%
# Loading the file from our drive
with open("/content/drive/Shareddrives/CSDS 234 Final Project/spotify_million_playlist_dataset/data/mpd.slice.0-999.json") as f:
    data = json.load(f)

# Creating our all-inclusive dataframe (df)

flattened_playlists = []
for playlist in data['playlists']:
    playlist_info = {
        'pid': playlist['pid'],
        'name': playlist.get('name', None),
        'collaborative': playlist['collaborative'],
        'modified_at': playlist['modified_at'],
        'num_tracks': playlist['num_tracks'],
        'num_albums': playlist['num_albums'],
        'num_followers': playlist['num_followers']
    }

    for track in playlist['tracks']:
        track_info = {
            'playlist_pid': playlist['pid'],
            'track_pos': track['pos'],
            'track_name': track['track_name'],
            'track_uri': track['track_uri'],
            'artist_name': track['artist_name'],
            'artist_uri': track['artist_uri'],
            'album_name': track['album_name'],
            'album_uri': track['album_uri'],
            'duration_ms': track['duration_ms']
        }
        flattened_playlists.append({**playlist_info, **track_info})

# Create a Pandas DataFrame for our schema
df = pd.DataFrame(flattened_playlists)

#View the first 10 tuples of our schema with 1000 playlists
df.head(10)
# Out:
#    pid        name collaborative  modified_at  num_tracks  num_albums  num_followers  playlist_pid  track_pos                                  track_name                             track_uri         artist_name                             artist_uri                                    album_name                             album_uri  duration_ms
# 0    0  Throwbacks         false   1493424000          52          47              1             0          0  Lose Control (feat. Ciara & Fat Man Scoop)  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI       Missy Elliott  spotify:artist:2wIVse2owClT7go1WT98tk                                  The Cookbook  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K       226863
# 1    0  Throwbacks         false   1493424000          52          47              1             0          1                                       Toxic  spotify:track:6I9VzXrHxO9rA9A5euc8Ak      Britney Spears  spotify:artist:26dSoYclwsYLMAKD3tpOr4                                   In The Zone  spotify:album:0z7pVBGOD7HCIB7S8eLkLI       198800
# 2    0  Throwbacks         false   1493424000          52          47              1             0          2                               Crazy In Love  spotify:track:0WqIKmW4BTrj3eJFmnCKMv             Beyoncé  spotify:artist:6vWDO969PvNqNYHIOW5v0m  Dangerously In Love (Alben für die Ewigkeit)  spotify:album:25hVFAxTlDvXbx2X2QkUkE       235933
# 3    0  Throwbacks         false   1493424000          52          47              1             0          3                              Rock Your Body  spotify:track:1AWQoqb9bSvzTjaLralEkT   Justin Timberlake  spotify:artist:31TPClRtHm23RisEBtV3X7                                     Justified  spotify:album:6QPkyl04rXwTGlGlcYaRoW       267266
# 4    0  Throwbacks         false   1493424000          52          47              1             0          4                                It Wasn't Me  spotify:track:1lzr43nnXAijIGYnCT8M8H              Shaggy  spotify:artist:5EvFsr3kj42KNv97ZEnqij                                      Hot Shot  spotify:album:6NmFmPX56pcLBOFMhIiKvF       227600
# 5    0  Throwbacks         false   1493424000          52          47              1             0          5                                       Yeah!  spotify:track:0XUfyU2QviPAs6bxSpXYG4               Usher  spotify:artist:23zg3TcAtWQy7J6upgbUnj                                   Confessions  spotify:album:0vO0b1AvY49CPQyVisJLj0       250373
# 6    0  Throwbacks         false   1493424000          52          47              1             0          6                                      My Boo  spotify:track:68vgtRHr7iZHpzGpon6Jlo               Usher  spotify:artist:23zg3TcAtWQy7J6upgbUnj                                   Confessions  spotify:album:1RM6MGv6bcl6NrAG8PGoZk       223440
# 7    0  Throwbacks         false   1493424000          52          47              1             0          7                                     Buttons  spotify:track:3BxWKCI06eQ5Od8TY2JBeA  The Pussycat Dolls  spotify:artist:6wPhSqRtPu1UhRCDX5yaDJ                                           PCD  spotify:album:5x8e8UcCeOgrOzSnDGuPye       225560
# 8    0  Throwbacks         false   1493424000          52          47              1             0          8                                 Say My Name  spotify:track:7H6ev70Weq6DdpZyyTmUXk     Destiny's Child  spotify:artist:1Y8cdNmUJH7yBTd9yOvr5i                     The Writing's On The Wall  spotify:album:283NWqNsCA9GwVHrJk59CG       271333
# 9    0  Throwbacks         false   1493424000          52          47              1             0          9              Hey Ya! - Radio Mix / Club Mix  spotify:track:2PpruBYCo4H7WOBJ7Q2EwM             OutKast  spotify:artist:1G9G7WwrXka3Z1r7aIDjI7                   Speakerboxxx/The Love Below  spotify:album:1UsmQ3bpJTyK6ygoOOjG1r       235213

# %%
# Originally we only had a portion of the 1000 playlists randomly selected so this command could be used if we wanted to randomly select for
# increasing our data frame size

#Clean the data by selecting the random playlists

clean_df = df.loc[df["pid"].isin(sample)]
# del(df, numbers) # Release unused memory

# clean_df: the all-inclusive dataframe with all columns provided by spotify for 1000 playlists
clean_df.head()
# Out:
#    pid        name collaborative  modified_at  num_tracks  num_albums  num_followers  playlist_pid  track_pos                                  track_name                             track_uri        artist_name                             artist_uri                                    album_name                             album_uri  duration_ms
# 0    0  Throwbacks         false   1493424000          52          47              1             0          0  Lose Control (feat. Ciara & Fat Man Scoop)  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI      Missy Elliott  spotify:artist:2wIVse2owClT7go1WT98tk                                  The Cookbook  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K       226863
# 1    0  Throwbacks         false   1493424000          52          47              1             0          1                                       Toxic  spotify:track:6I9VzXrHxO9rA9A5euc8Ak     Britney Spears  spotify:artist:26dSoYclwsYLMAKD3tpOr4                                   In The Zone  spotify:album:0z7pVBGOD7HCIB7S8eLkLI       198800
# 2    0  Throwbacks         false   1493424000          52          47              1             0          2                               Crazy In Love  spotify:track:0WqIKmW4BTrj3eJFmnCKMv            Beyoncé  spotify:artist:6vWDO969PvNqNYHIOW5v0m  Dangerously In Love (Alben für die Ewigkeit)  spotify:album:25hVFAxTlDvXbx2X2QkUkE       235933
# 3    0  Throwbacks         false   1493424000          52          47              1             0          3                              Rock Your Body  spotify:track:1AWQoqb9bSvzTjaLralEkT  Justin Timberlake  spotify:artist:31TPClRtHm23RisEBtV3X7                                     Justified  spotify:album:6QPkyl04rXwTGlGlcYaRoW       267266
# 4    0  Throwbacks         false   1493424000          52          47              1             0          4                                It Wasn't Me  spotify:track:1lzr43nnXAijIGYnCT8M8H             Shaggy  spotify:artist:5EvFsr3kj42KNv97ZEnqij                                      Hot Shot  spotify:album:6NmFmPX56pcLBOFMhIiKvF       227600

# %% [markdown]
# Before we start it is useful to gain some insights on the data we are working with. This will give us a better idea of what we need to clean and analyze.

# %%
print("Total Number of Songs: ", len(set(clean_df["track_name"])))
print("Total Number of Playlists: ", len(set(clean_df["pid"])))
print("Average Number of Songs in a Playlist: ", (len(set(clean_df["track_name"])))/ len(set(clean_df["pid"])))
# Out:
# Total Number of Songs:  30049
# Total Number of Playlists:  1000
# Average Number of Songs in a Playlist:  30.049

# %%
pyplot.hist(clean_df['pid'].value_counts())
pyplot.title("Distribution of the Number of Songs in Our 1000 Playlists")
pyplot.ylabel("Count")
pyplot.xlabel("Number of songs in a playlist")
pyplot.show()

# %%
# Checking which artists are featured most across all playlists
values = list(clean_df['artist_name'].value_counts())
names = clean_df['artist_name'].value_counts().index.tolist()

ax = sns.barplot(y=names[0:10], x=values[0:10])
ax.set_title('Artists with most featured songs across all playlists')
ax.set_xlabel('Total songs across playlists')
# Out:
# Text(0.5, 0, 'Total songs across playlists')

# %% [markdown]
# Here we see that Drake shows up in many of the playlists. While he is a really popular artist, this may indicate that our playlist recommendation model is better for those who like Drake. To address this issue we could process more playlists, but because of hardware limitations this is the training data set we are working with.

# %% [markdown]
# # Test Data

# %% [markdown]
# ## Cleaning and Preprocessing

# %%
#Randomly select a different JSON file with new playlist data to avoid selecting playlists from our training playlists

file_name_list = ['1000-1999', '2000-2999', '3000-3999', '4000-4999', '5000-5999', '6000-6999', '7000-7999', '8000-8999', '9000-9999']
np.random.seed(seed=18) # This seed yield '4000-4999'
selected_file = np.random.choice(file_name_list)

with open("/content/drive/Shareddrives/CSDS 234 Final Project/spotify_million_playlist_dataset/data/mpd.slice."+ selected_file + ".json") as g:
    data = json.load(g)

    test_playlists = []
for playlist in data['playlists']:
    playlist_info = {
        'pid': playlist['pid'],
        'name': playlist.get('name', None),
        'collaborative': playlist['collaborative'],
        'modified_at': playlist['modified_at'],
        'num_tracks': playlist['num_tracks'],
        'num_albums': playlist['num_albums'],
        'num_followers': playlist['num_followers']
    }

    for track in playlist['tracks']:
        track_info = {
            #'playlist_pid': playlist['pid'], # is this a redudant variable?
            'track_pos': track['pos'],
            'track_name': track['track_name'],
            'track_uri': track['track_uri'],
            'artist_name': track['artist_name'],
            'artist_uri': track['artist_uri'],
            'album_name': track['album_name'],
            'album_uri': track['album_uri'],
            'duration_ms': track['duration_ms']
        }
        test_playlists.append({**playlist_info, **track_info})

# Create a Pandas DataFrame to store the test playlists
test1000_df = pd.DataFrame(test_playlists)
test1000_df.head(10)
# Out:
#     pid   name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                                         track_name                             track_uri                      artist_name                             artist_uri                                         album_name                             album_uri  duration_ms
# 0  4000  skate          true   1432252800          70          62              1          0                                            Circles  spotify:track:53yXbISmPFewWiFP2kgal8                        Ty Segall  spotify:artist:58XGUNsRNu3cVOIOYk5chx                                           Mr. Face  spotify:album:5bXUYhd6yvmry49a8WpEqS       186176
# 1  4000  skate          true   1432252800          70          62              1          1                                      Ramble Tamble  spotify:track:47atuTch0AN7NvP9vp42a5     Creedence Clearwater Revival  spotify:artist:3IYUhFvPQItj6xySrBmZkd                                    Cosmo's Factory  spotify:album:4GLxEXWI3JiRKp6H7bfTIK       431226
# 2  4000  skate          true   1432252800          70          62              1          2                                          Brendan 1  spotify:track:7uzeJ1HasqTqqB2anNRFCs                           Fugazi  spotify:artist:62sC6lUEWRjbFqXpMmOk4G                                           Repeater  spotify:album:3ZnF1cPxlqB48RyLiecDnv       152493
# 3  4000  skate          true   1432252800          70          62              1          3                             Death of a Ladies' Man  spotify:track:5wrylUGwZugelovhryPYg2                    Leonard Cohen  spotify:artist:5l8VQNuIg0turYE1VtM9zV                             Death Of A Ladies' Man  spotify:album:0qghwsBOHAhmIukaW08IOT       564133
# 4  4000  skate          true   1432252800          70          62              1          4                       After Laughter (Comes Tears)  spotify:track:2bsAzwSesOofKlc8ip4MB7                       Wendy Rene  spotify:artist:4ba7uNtpOq0us2C5Nx19zN  After Laughter Comes Tears: Complete Stax & Vo...  spotify:album:6lSJwPx7Sqdl7nGLHb3mkG       182893
# 5  4000  skate          true   1432252800          70          62              1          5                           How You Doin, Here We Go  spotify:track:3OWgczPOsu1xCWV5ClpV8Q   Ray Barbee Meets the Mattson 2  spotify:artist:6980BgFWNc5h3wbuhA6QTm                      Ray Barbee Meet the Mattson 2  spotify:album:3RxFFFMvhjB87uLFSXzdl2        73600
# 6  4000  skate          true   1432252800          70          62              1          6  Please, Please, Please - Live At The Apollo Th...  spotify:track:0HOqGdqxLZN68sdm06LDiV  James Brown & The Famous Flames  spotify:artist:32r72WOqqRO1DtSznId7Lr                       'Live' At The Apollo Vol. II  spotify:album:7um5ZTFpHJQCbBdOdLbsCg       161466
# 7  4000  skate          true   1432252800          70          62              1          7                                         Wild Witch  spotify:track:5SHcOU4noUpL9OU3rnWxXl                       Restavrant  spotify:artist:64Xip1q4drLaPRLqHXlzBU                             Yeah, I Carve Cheetahs  spotify:album:2CYymhzoMGZIYUrFXh0WBO       210430
# 8  4000  skate          true   1432252800          70          62              1          8                                        Gut Feeling  spotify:track:4fNbrazMYC1CbalcQ8YFGC                             DEVO  spotify:artist:0UKfenbZb15sqhfPC6zbt3                 The Life Aquatic With Steve Zissou  spotify:album:05mpXOy7NNlc3oGqNathD6       247160
# 9  4000  skate          true   1432252800          70          62              1          9                                 Good Morning Judge  spotify:track:0wLFcJ5jPNnpGwSdZ0JSG2                      Furry Lewis  spotify:artist:66SiMdpsWXE23qqX0JaWg9                                 Good Morning Judge  spotify:album:4SejT5bBFYH6qC9ikemWl2       331333

# %%
"""
We chose playlists (pids) with greater than 100 songs so that our model has at least 30 songs to work with if we
split 70% of the playlist into training and the other 30% into testing, we'd still have about our average playlist size
of 70 songs for our model to provide 30 recommendations for.
"""
# Filter playlists with between 100 and 200 tracks
large_test_pl = test1000_df[(test1000_df['num_tracks'] >= 90) & (test1000_df['num_tracks'] <= 200)]

# Randomly select 25 unique playlist pids
selected_playlist_pids = large_test_pl['pid'].sample(n=26, random_state=18).tolist()

# Filter the DataFrame to include only rows corresponding to the selected playlist pids
test_playlists = large_test_pl[large_test_pl['pid'].isin(selected_playlist_pids)]

# Display the first 10 tuples selected playlists
print(test_playlists.head(10))

# Display the pids of the selected playlists
print(test_playlists['pid'].unique())
# Out:
#       pid  name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                      track_name                             track_uri           artist_name                             artist_uri                         album_name                             album_uri  duration_ms
# 101  4003  HOLA         false   1493424000         104          89              2          0  La Botella (Pasame La Botella)  spotify:track:48RhiOqPE7d817wb2OzlNN      Reggaeton Latino  spotify:artist:3sG7WHWEWaSVehXJRj7t4n                Reggaeton Best Hits  spotify:album:0pH52976tC7WkVa5wCz8Lk       182946
# 102  4003  HOLA         false   1493424000         104          89              2          1   Hasta el Amanecer - The Remix  spotify:track:4bisT9khxJYFKaoG8pxq5h             Nicky Jam  spotify:artist:1SupJlEpv7RS2tPNRaHViT                              Fénix  spotify:album:2dBgWXp41imu2zBNv9oFxZ       188466
# 103  4003  HOLA         false   1493424000         104          89              2          2              Andas En Mi Cabeza  spotify:track:5mey7CLLuFToM2P68Qu1gF         Chino & Nacho  spotify:artist:5NS0854TqZQVoRmJKSWtFZ                 Andas En Mi Cabeza  spotify:album:5Ai3DmyYkShDJ5OdvjqT5a       247493
# 104  4003  HOLA         false   1493424000         104          89              2          3                 Desde Esa Noche  spotify:track:1pWYnQIlqxTh5bxuPmTG4E                Thalía  spotify:artist:23wEWD21D4TPYiJugoXmYb                             Latina  spotify:album:4hQcPgUoOykA7IzS6av6ox       227693
# 105  4003  HOLA         false   1493424000         104          89              2          4                    Maria Se Fue  spotify:track:1IqzjgnTD8YqOkO6fr40li            Oro Solido  spotify:artist:7wLYNBd1fXGEKSLJMNnlt4                   Best Of The Best  spotify:album:16GgLICbOKpyo2XH4Dmbcs       278120
# 106  4003  HOLA         false   1493424000         104          89              2          5                       Guallando  spotify:track:4jRxEVNituPZObHbCSBZL3              Fulanito  spotify:artist:0hD97064k3LBUrRvfT42SE  El Hombre Mas Famoso De La Tierra  spotify:album:59IdVahjfUKyRxPcGiAp98       205333
# 107  4003  HOLA         false   1493424000         104          89              2          6                      El Cepillo  spotify:track:2EWZswsvSERfAWzXPE2trG              Fulanito  spotify:artist:0hD97064k3LBUrRvfT42SE                      Greatest Hits  spotify:album:2se2DHy9J2L20JV02zwQHx       206493
# 108  4003  HOLA         false   1493424000         104          89              2          7                       Chiquilla  spotify:track:4RcN7qGRs4OfbI8cHmqQiL  A.B. Quintanilla III  spotify:artist:5MP9bH9aUryiKQeUvABLIU        From KK to Kumbia All-Starz  spotify:album:16cRWklmy1DIKkYufsAJMb       210306
# 109  4003  HOLA         false   1493424000         104          89              2          8               Baila Esta Cumbia  spotify:track:3lFGBrRWUxpTfhhq6lGBRw                Selena  spotify:artist:6IE6z7DcZIT4Ml3Fh5Ivch                         La Leyenda  spotify:album:058VOHYTS6kFauVUl6Eh03       161906
# 110  4003  HOLA         false   1493424000         104          89              2          9                  Mi Cucu|cumbia  spotify:track:7JVnOxdBvTdSZicDTCHvcu     Cumbia Latin Band  spotify:artist:3cP35T1YmIDyrwfHrIVbeh                       Cumbia Party  spotify:album:2S6jEPU5f4Y04e3nY65AOQ       236666
# [4003 4129 4130 4131 4133 4138 4175 4179 4191 4226 4296 4367 4395 4410
#  4471 4516 4530 4594 4653 4751 4762 4783 4811 4967 4998]

# %% [markdown]
# ## Splitting the Test Data

# %%
"""
This is a function to break down a data frame of all playlists into separate dfs for a single playlist

Input: A large dataframe with several playlists
Output: A dictionary indexed by pid for each single playlist dataframe
"""
def store_single(df):
  playlists_dict = {}
  for pid in df['pid'].unique():
    playlist = df[df['pid'] == pid]
    playlists_dict[pid] = playlist.copy()  # Store each playlist in the dictionary

  return playlists_dict

# Splitting playlists into dataframes for each playlist
playlist_catalog = store_single(test_playlists)

print(playlist_catalog[4003])
print(playlist_catalog.keys())
# Out:
#       pid  name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                      track_name                             track_uri           artist_name                             artist_uri           album_name                             album_uri  duration_ms
# 101  4003  HOLA         false   1493424000         104          89              2          0  La Botella (Pasame La Botella)  spotify:track:48RhiOqPE7d817wb2OzlNN      Reggaeton Latino  spotify:artist:3sG7WHWEWaSVehXJRj7t4n  Reggaeton Best Hits  spotify:album:0pH52976tC7WkVa5wCz8Lk       182946
# 102  4003  HOLA         false   1493424000         104          89              2          1   Hasta el Amanecer - The Remix  spotify:track:4bisT9khxJYFKaoG8pxq5h             Nicky Jam  spotify:artist:1SupJlEpv7RS2tPNRaHViT                Fénix  spotify:album:2dBgWXp41imu2zBNv9oFxZ       188466
# 103  4003  HOLA         false   1493424000         104          89              2          2              Andas En Mi Cabeza  spotify:track:5mey7CLLuFToM2P68Qu1gF         Chino & Nacho  spotify:artist:5NS0854TqZQVoRmJKSWtFZ   Andas En Mi Cabeza  spotify:album:5Ai3DmyYkShDJ5OdvjqT5a       247493
# 104  4003  HOLA         false   1493424000         104          89              2          3                 Desde Esa Noche  spotify:track:1pWYnQIlqxTh5bxuPmTG4E                Thalía  spotify:artist:23wEWD21D4TPYiJugoXmYb               Latina  spotify:album:4hQcPgUoOykA7IzS6av6ox       227693
# 105  4003  HOLA         false   1493424000         104          89              2          4                    Maria Se Fue  spotify:track:1IqzjgnTD8YqOkO6fr40li            Oro Solido  spotify:artist:7wLYNBd1fXGEKSLJMNnlt4     Best Of The Best  spotify:album:16GgLICbOKpyo2XH4Dmbcs       278120
# ..    ...   ...           ...          ...         ...         ...            ...        ...                             ...                                   ...                   ...                                    ...                  ...                                   ...          ...
# 200  4003  HOLA         false   1493424000         104          89              2         99           Na Na Na (Dulce Niña)  spotify:track:6M870HixVgIS4VTudBHcz8  A.B. Quintanilla III  spotify:artist:5MP9bH9aUryiKQeUvABLIU                Fuego  spotify:album:1CJEE36qrJYAUXVJuVQ7ne       205093
# 201  4003  HOLA         false   1493424000         104          89              2        100         Yo No Sé Mañana (salsa)  spotify:track:1nZziTuPRwCfJe1XvVC760          Luis Enrique  spotify:artist:2mUI4K6csTQd3jieswcmiI               Ciclos  spotify:album:0UhRsOyE3SzdM51cjS3LVm       259853
# 202  4003  HOLA         false   1493424000         104          89              2        101                    Vente Pa' Ca  spotify:track:7DM4BPaS7uofFul3ywMe46          Ricky Martin  spotify:artist:7slfeZO9LsJbWgpkIoXBUJ         Vente Pa' Ca  spotify:album:1FkaJUwfqLdQdSmRPBlw6l       259195
# 203  4003  HOLA         false   1493424000         104          89              2        102                       El Amante  spotify:track:3umS4y3uQDkqekNjVpiRUs             Nicky Jam  spotify:artist:1SupJlEpv7RS2tPNRaHViT                Fénix  spotify:album:2dBgWXp41imu2zBNv9oFxZ       219506
# 204  4003  HOLA         false   1493424000         104          89              2        103           Bailando por el Mundo  spotify:track:4hLEorB47NotMkSLCWmh5e            Juan Magán  spotify:artist:1ackd5XprZEkH3McKbQD51    The King Of Dance  spotify:album:67hCGmMfz8cg2YLO0xZWnx       197240
#
# [104 rows x 15 columns]
# dict_keys([4003, 4129, 4130, 4131, 4133, 4138, 4175, 4179, 4191, 4226, 4296, 4367, 4395, 4410, 4471, 4516, 4530, 4594, 4653, 4751, 4762, 4783, 4811, 4967, 4998])

# %%
"""
Here we need to split our test playlists 0.7:0.3 training to test data.
We will need to select 30% of the playlist and store it for cross checking recommendations later.

If we are recommending for many playlists at once, we want to interate through each playlist df in the catalog
and split them into training and test data. We will use an imported function to make this easier/ more efficient.


Input: A dictionary of playlists with tracks in dataframes
Output: Dictionaries for the training and test dataframes
"""

def split_group(playlist_catalog):
  train_playlists_dict = {}
  test_playlists_dict = {}

  # Assuming playlist_catalog is a dictionary containing playlists
  for key in playlist_catalog:
    playlist = playlist_catalog[key]  # Get the playlist dataframe for the current key

    # Splitting the current playlist into 70% train and 30% test
    train_playlist, test_playlist = train_test_split(playlist, test_size=0.3)

    # Storing the split playlists in separate dictionaries
    train_playlists_dict[key] = train_playlist
    test_playlists_dict[key] = test_playlist

  return train_playlists_dict, test_playlists_dict

train_playlists_dict, test_playlists_dict = split_group(playlist_catalog)

print(train_playlists_dict[4003].shape) # This will tell us how many songs were split from the orig playlist to the training and test dfs
print(test_playlists_dict[4003].shape)
# Out:
# (72, 15)
# (32, 15)

# %% [markdown]
# ## Combining the Data

# %%
"""
Join the input training dataframe to the 1000 dataframe with a function

Input: The dataframe with the additional training playlist

Output: The original playlist dataframe with some of the songs from the inputted playlist

"""
def join_data(add_pl_df):
  frames = [clean_df, add_pl_df]
  join_df = pd.concat(frames)
  return join_df

# Test it with the first playlist in the test dict 4003
# join_df will be used most often going forth as it is the dataframe which we'll base our suggestions off of
join_df = join_data(train_playlists_dict[4003])
join_df
# Out:
#       pid        name collaborative  modified_at  num_tracks  num_albums  num_followers  playlist_pid  track_pos                                  track_name                             track_uri             artist_name                             artist_uri                                    album_name                             album_uri  duration_ms
# 0       0  Throwbacks         false   1493424000          52          47              1           0.0          0  Lose Control (feat. Ciara & Fat Man Scoop)  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI           Missy Elliott  spotify:artist:2wIVse2owClT7go1WT98tk                                  The Cookbook  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K       226863
# 1       0  Throwbacks         false   1493424000          52          47              1           0.0          1                                       Toxic  spotify:track:6I9VzXrHxO9rA9A5euc8Ak          Britney Spears  spotify:artist:26dSoYclwsYLMAKD3tpOr4                                   In The Zone  spotify:album:0z7pVBGOD7HCIB7S8eLkLI       198800
# 2       0  Throwbacks         false   1493424000          52          47              1           0.0          2                               Crazy In Love  spotify:track:0WqIKmW4BTrj3eJFmnCKMv                 Beyoncé  spotify:artist:6vWDO969PvNqNYHIOW5v0m  Dangerously In Love (Alben für die Ewigkeit)  spotify:album:25hVFAxTlDvXbx2X2QkUkE       235933
# 3       0  Throwbacks         false   1493424000          52          47              1           0.0          3                              Rock Your Body  spotify:track:1AWQoqb9bSvzTjaLralEkT       Justin Timberlake  spotify:artist:31TPClRtHm23RisEBtV3X7                                     Justified  spotify:album:6QPkyl04rXwTGlGlcYaRoW       267266
# 4       0  Throwbacks         false   1493424000          52          47              1           0.0          4                                It Wasn't Me  spotify:track:1lzr43nnXAijIGYnCT8M8H                  Shaggy  spotify:artist:5EvFsr3kj42KNv97ZEnqij                                      Hot Shot  spotify:album:6NmFmPX56pcLBOFMhIiKvF       227600
# ..    ...         ...           ...          ...         ...         ...            ...           ...        ...                                         ...                                   ...                     ...                                    ...                                           ...                                   ...          ...
# 167  4003        HOLA         false   1493424000         104          89              2           NaN         66                                    La Chona  spotify:track:79xkyiTBHqdGg3SirACPwy  Los Tucanes De Tijuana  spotify:artist:014WIDx7H4BRCHB1faiisK                Para Tucancillos y Tucancillas  spotify:album:3oeX8Q7k6jH4Gq8WzRkNqb       199080
# 147  4003        HOLA         false   1493424000         104          89              2           NaN         46                                   El Perdón  spotify:track:7qCAVkHWZkF44OzOUKf8Cr               Nicky Jam  spotify:artist:1SupJlEpv7RS2tPNRaHViT                                         Fénix  spotify:album:2dBgWXp41imu2zBNv9oFxZ       205906
# 150  4003        HOLA         false   1493424000         104          89              2           NaN         49                                 La Charanga  spotify:track:1l6cp61AJPW71r3isZ6UBJ     Los Pumas Del Norte  spotify:artist:7oDAL6I6hsVHfn0ADFYpmh               Impresionantes Huellas Nortenas  spotify:album:0vlyMrJlRspc7LdG3zxUGB       229666
# 163  4003        HOLA         false   1493424000         104          89              2           NaN         62        Me Puedo Matar (feat. Hactor Acosta)  spotify:track:0LZQnaXoK56LjyLkTv2pKQ         Bachata Heightz  spotify:artist:5zvRX0y0JYtGOmGJwLwyIL                                La Mega Mezcla  spotify:album:5vysmao1LqnKFihfi7SBXD       264853
# 170  4003        HOLA         false   1493424000         104          89              2           NaN         69                             Payaso de Rodeo  spotify:track:0EVcfyLGhkvm2RMXMWI456          Caballo Dorado  spotify:artist:38yOUctO9eek9ti5NWMQXm                               Payaso de rodeo  spotify:album:1NMqmkX9KhLoy5fXxtiS5S       254666
#
# [67575 rows x 16 columns]

# %% [markdown]
# # Creating the sparse matrix

# %%
# Create a sparse matrix of song in playlist as a dataframe
from scipy import sparse

def Sparse_Matrix(matrix_df):
  pl_song_df = pd.crosstab(index=matrix_df['pid'], columns=matrix_df['track_name'])
  pl_song_matrix = sparse.csr_matrix(pl_song_df)
  return pl_song_matrix

pl_song_matrix = Sparse_Matrix(join_df)

# %% [markdown]
# # K-Nearest Neighbor (KNN) Model

# %% [markdown]
# ## In-between steps of cleaning for the model

# %%
from sklearn.neighbors import NearestNeighbors

model_knn = NearestNeighbors(metric='cosine', algorithm='brute')
model_knn.fit(pl_song_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
distances, indices = model_knn.kneighbors(pl_song_matrix, n_neighbors=50)
distances, indices

# After this command the indices do not correspond with the original pids
# Out:
# (array([[9.99200722e-16, 7.59530527e-01, 8.16273915e-01, ...,
#          9.49460130e-01, 9.50101254e-01, 9.50492623e-01],
#         [0.00000000e+00, 8.55314211e-01, 8.61324951e-01, ...,
#          9.68444208e-01, 9.69183322e-01, 9.69738623e-01],
#         [0.00000000e+00, 8.76908509e-01, 9.73349910e-01, ...,
#          1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#         ...,
#         [2.55351296e-15, 7.47562632e-01, 7.99732799e-01, ...,
#          9.60237861e-01, 9.60237861e-01, 9.62780632e-01],
#         [5.55111512e-16, 9.43659960e-01, 9.49748109e-01, ...,
#          9.81718189e-01, 9.82475009e-01, 9.82475009e-01],
#         [0.00000000e+00, 8.60439451e-01, 9.04706765e-01, ...,
#          1.00000000e+00, 1.00000000e+00, 1.00000000e+00]]),
#  array([[   0,  262,  747, ...,  872,  105,  542],
#         [   1,  637,  580, ...,  120,  494,  474],
#         [   2,   88,  238, ...,  662,  640,  742],
#         ...,
#         [ 998,  803,  479, ...,  628,    5,   64],
#         [ 999,  475,  795, ...,  722,  167,   85],
#         [1000,  212,  506, ...,  668,  667,  678]]))

# %%
# get the indicies of the closest neighbors

def get_nearest_neighbors_indices(unindexed_neighbors, original_dataframe):
    neighbors = []
    for item in unindexed_neighbors[0][1:]:  # Skip the first index, because that is the query playlist itself
        pid = list(set(original_dataframe['pid']))[item]
        neighbors.append(pid)

    return neighbors

neighbors = get_nearest_neighbors_indices(indices, join_df)

# %%
#clean the dataframe to ones only containing the neighbors
def clean_neighbors(neighbors, df):
  rec_pl_df = df.loc[df['pid'].isin(neighbors)]
  rec_pl_df = rec_pl_df[['pid', 'track_uri', 'track_name','artist_name']]
  return rec_pl_df

rec_pl_df = clean_neighbors(neighbors, join_df)
rec_pl_df
# Out:
#        pid                             track_uri             track_name    artist_name
# 2095    38  spotify:track:1hGy2eLcmC8eKx7qr1tOqx        Beautiful Girls  Sean Kingston
# 2096    38  spotify:track:4fINc8dnfcz7AdhFYVA4i7                It Girl   Jason Derulo
# 2097    38  spotify:track:4E5P1XyAFtrjpiIxkydly4                 Replay           Iyaz
# 2098    38  spotify:track:2oENJa1T33GJ0w8dC167G4           Fire Burning  Sean Kingston
# 2099    38  spotify:track:5BoIP8Eha5hwmRVURkC2Us             In My Head   Jason Derulo
# ...    ...                                   ...                    ...            ...
# 67070  992  spotify:track:1CdkNxTlkUWR4ZnXcKES3b               With You    Chris Brown
# 67071  992  spotify:track:4z8c9qkpiYghn6DCQ6yA0u  Simple Things (Remix)         Miguel
# 67072  992  spotify:track:3wu9ADop1FXdhToPCxwBL8          Take You Down    Chris Brown
# 67073  992  spotify:track:1LiC33bHDw8ZVNTKuT0ngr          Play No Games       Big Sean
# 67074  992  spotify:track:22DLRC6Uswi8CogicodKpT                  Ready       Fabolous
#
# [4282 rows x 4 columns]

# %%
# Get the track_uri of the recommended songs by adding up the apperance of individual song across the neighbor playlists
def get_song_recommendations(input_pl,rec_pl_df, neighbors, df, top_n=20):
  rec_pl_df = df.loc[join_df['pid'].isin(neighbors)]
  rec_pl_df = rec_pl_df[['pid', 'track_uri', 'track_name','artist_name']]
  song_recs = {}
  top_n_songs = []
  i = 0
# create a dict key entry for each song to record the times it appear across the playlists
  for song in list(rec_pl_df['track_uri']):
    if song not in song_recs:
      song_recs[song] = 1
    else:
      song_recs[song] += 1
  sorted_song_recs = sorted(song_recs.items(), key=lambda x:x[1], reverse = True)

#add the songs only if it is not already in the input playlist
  for rec_song in sorted_song_recs:
    if rec_song[0] not in set(input_pl['track_uri']) and i < top_n:
      top_n_songs.append(rec_song)
      i += 1
    elif i > top_n:
      return top_n_songs
  return top_n_songs

#test for now
test_4003_df = test_playlists[test_playlists['pid'].isin([4003])]
sorted_song_recs = get_song_recommendations(test_4003_df, rec_pl_df, neighbors, join_df)

sorted_song_recs
# Out:
# [('spotify:track:0XUfyU2QviPAs6bxSpXYG4', 19),
#  ('spotify:track:0WqIKmW4BTrj3eJFmnCKMv', 15),
#  ('spotify:track:2PpruBYCo4H7WOBJ7Q2EwM', 13),
#  ('spotify:track:5XJJdNPkwmbUwE79gv0NxK', 13),
#  ('spotify:track:5Q0Nhxo0l2bP3pNjpGJwV1', 13),
#  ('spotify:track:4E5P1XyAFtrjpiIxkydly4', 11),
#  ('spotify:track:5dNfHmqgr128gMY2tc5CeJ', 11),
#  ('spotify:track:6RcQOut9fWL6FSqeIr5M1r', 11),
#  ('spotify:track:5y69gQtK33qxb8a24ACkCy', 11),
#  ('spotify:track:3VzJE6yGuj8fDExUh6TLnc', 11),
#  ('spotify:track:7BKLCZ1jbUBVqRi2FVlTVw', 11),
#  ('spotify:track:67T6l4q3zVjC5nZZPXByU8', 10),
#  ('spotify:track:2gam98EZKrF9XuOkU13ApN', 10),
#  ('spotify:track:4gFXY5yvHayGckJndafYQE', 10),
#  ('spotify:track:1lzr43nnXAijIGYnCT8M8H', 10),
#  ('spotify:track:7iL6o9tox1zgHpKUfh9vuC', 10),
#  ('spotify:track:0azC730Exh71aQlOt9Zj3y', 10),
#  ('spotify:track:66TRwr5uJwPt15mfFkzhbi', 10),
#  ('spotify:track:5KY7zgFeH2GWoL1zP9mME6', 9),
#  ('spotify:track:2q4rjDy9WhaN3o9MvDbO21', 9)]

# %%
#get track informations such as track names and artists
def get_info(track_uri_list, cleaned_data):

  top_n_recs_info = []

  for song_uri, count in track_uri_list:
        # Check if the song URI exists in cleaned_data
        song_info = cleaned_data[(cleaned_data['track_uri'] == song_uri)]
        if not song_info.empty:
            track_name = song_info['track_name'].iloc[0]
            artist_name = song_info['artist_name'].iloc[0]
            combined_info = f"{track_name} - {artist_name}"
            top_n_recs_info.append(combined_info)
        else:
            print(song_uri)
            top_n_recs_info.append("Track info not found")

  return top_n_recs_info

top_n_songs_final = get_info(sorted_song_recs, rec_pl_df)
top_n_songs_final
# Out:
# ['Yeah! - Usher',
#  'Crazy In Love - Beyoncé',
#  'Hey Ya! - Radio Mix / Club Mix - OutKast',
#  'Gold Digger - Kanye West',
#  'Party In The U.S.A. - Miley Cyrus',
#  'Replay - Iyaz',
#  'Ignition - Remix - R. Kelly',
#  'Hollaback Girl - Gwen Stefani',
#  'A Thousand Miles - Vanessa Carlton',
#  'Candy Shop - 50 Cent',
#  'Closer - The Chainsmokers',
#  'Whatcha Say - Jason Derulo',
#  'Promiscuous - Nelly Furtado',
#  "Buy U a Drank (Shawty Snappin') - T-Pain",
#  "It Wasn't Me - Shaggy",
#  'In Da Club - 50 Cent',
#  'This Is What You Came For - Calvin Harris',
#  'Crank That (Soulja Boy) - Soulja Boy',
#  'Get Low - Street - Lil Jon & The East Side Boyz',
#  'Kiss Me Thru The Phone - Soulja Boy']

# %% [markdown]
# ## The Recommendation Function!!!!

# %%
# recommend songs to the input playlist by combining all functions above
def recommend_songs(my_pl_df, num):
  join = join_data(my_pl_df)
  join_matrix = Sparse_Matrix(join)
  model_knn = NearestNeighbors(metric='cosine', algorithm='brute')
  model_knn.fit(join_matrix)
  distances, indices = model_knn.kneighbors(join_matrix, n_neighbors=50)
  neighbors =  get_nearest_neighbors_indices(indices, join)
  cleaned_nbors = clean_neighbors(neighbors, join)
  return get_info(get_song_recommendations(my_pl_df, cleaned_nbors, neighbors, join_df, num), cleaned_nbors)

test_4003_df = test_playlists[test_playlists['pid'].isin([4003])]

recommend_songs(test_4003_df, 50)
# Out:
# ['Yeah! - Usher',
#  'Crazy In Love - Beyoncé',
#  'Hey Ya! - Radio Mix / Club Mix - OutKast',
#  'Gold Digger - Kanye West',
#  'Party In The U.S.A. - Miley Cyrus',
#  'Replay - Iyaz',
#  'Ignition - Remix - R. Kelly',
#  'Hollaback Girl - Gwen Stefani',
#  'A Thousand Miles - Vanessa Carlton',
#  'Candy Shop - 50 Cent',
#  'Closer - The Chainsmokers',
#  'Whatcha Say - Jason Derulo',
#  'Promiscuous - Nelly Furtado',
#  "Buy U a Drank (Shawty Snappin') - T-Pain",
#  "It Wasn't Me - Shaggy",
#  'In Da Club - 50 Cent',
#  'This Is What You Came For - Calvin Harris',
#  'Crank That (Soulja Boy) - Soulja Boy',
#  'Get Low - Street - Lil Jon & The East Side Boyz',
#  'Kiss Me Thru The Phone - Soulja Boy',
#  'Work from Home - Fifth Harmony',
#  'One Dance - Drake',
#  'Forever - Chris Brown',
#  'Fireflies - Owl City',
#  'Fergalicious - Fergie',
#  'Beautiful Girls - Sean Kingston',
#  'One, Two Step - Ciara',
#  'Umbrella - Rihanna',
#  'Girlfriend (German Version - Explicit) - German Version - Explicit - Avril Lavigne',
#  'Panda - Desiigner',
#  'Sorry - Justin Bieber',
#  'Dynamite - Taio Cruz',
#  'Low (feat T-Pain) - Feat T-Pain Album Version - Flo Rida',
#  "Stacy's Mom - Fountains Of Wayne",
#  "Don't Tell 'Em - Jeremih",
#  'Trap Queen - Fetty Wap',
#  'The Motto - Drake',
#  'Stronger - Kanye West',
#  'California Gurls - feat. Snoop Dogg - Katy Perry',
#  "Don't Stop The Music - Rihanna",
#  'Mr. Brightside - The Killers',
#  'Disturbia - Rihanna',
#  'Sexy Can I feat. Yung Berg - Ray J',
#  'I Write Sins Not Tragedies - Panic! At The Disco',
#  'Pony - Ginuwine',
#  'Toxic - Britney Spears',
#  "I'm Yours - Jason Mraz",
#  'Dirty Little Secret - The All-American Rejects',
#  '1985 - Bowling For Soup',
#  'Sk8er Boi - Avril Lavigne']

# %% [markdown]
# # Metrics for Testing

# %% [markdown]
# ## R-Precision Test

# %% [markdown]
# R-precision is the number of retrieved relevant tracks divided by the number of known relevant tracks (i.e., the number of withheld tracks):
#
# $\text{R-precision} = \frac{\left| G \cap R_{1:|G|} \right|}{|G|}$
#
# The metric is averaged across all playlists in the challenge set. This metric rewards total number of retrieved relevant tracks (regardless of order).

# %%
# for the r-ptrcision test, we will instead make the function return the track uri
def recommend_songs_test(my_pl_df, num):
  join = join_data(my_pl_df)
  join_matrix = Sparse_Matrix(join)
  model_knn = NearestNeighbors(metric='cosine', algorithm='brute')
  model_knn.fit(join_matrix)
  distances, indices = model_knn.kneighbors(join_matrix, n_neighbors=50)
  neighbors =  get_nearest_neighbors_indices(indices, join)
  cleaned_nbors = clean_neighbors(neighbors, join)
  return get_song_recommendations(my_pl_df, cleaned_nbors, neighbors, join_df, num)

test_4003_df = test_playlists[test_playlists['pid'].isin([4003])]

recommend_songs_test(test_4003_df, 50)
# Out:
# [('spotify:track:0XUfyU2QviPAs6bxSpXYG4', 19),
#  ('spotify:track:0WqIKmW4BTrj3eJFmnCKMv', 15),
#  ('spotify:track:2PpruBYCo4H7WOBJ7Q2EwM', 13),
#  ('spotify:track:5XJJdNPkwmbUwE79gv0NxK', 13),
#  ('spotify:track:5Q0Nhxo0l2bP3pNjpGJwV1', 13),
#  ('spotify:track:4E5P1XyAFtrjpiIxkydly4', 11),
#  ('spotify:track:5dNfHmqgr128gMY2tc5CeJ', 11),
#  ('spotify:track:6RcQOut9fWL6FSqeIr5M1r', 11),
#  ('spotify:track:5y69gQtK33qxb8a24ACkCy', 11),
#  ('spotify:track:3VzJE6yGuj8fDExUh6TLnc', 11),
#  ('spotify:track:7BKLCZ1jbUBVqRi2FVlTVw', 11),
#  ('spotify:track:67T6l4q3zVjC5nZZPXByU8', 10),
#  ('spotify:track:2gam98EZKrF9XuOkU13ApN', 10),
#  ('spotify:track:4gFXY5yvHayGckJndafYQE', 10),
#  ('spotify:track:1lzr43nnXAijIGYnCT8M8H', 10),
#  ('spotify:track:7iL6o9tox1zgHpKUfh9vuC', 10),
#  ('spotify:track:0azC730Exh71aQlOt9Zj3y', 10),
#  ('spotify:track:66TRwr5uJwPt15mfFkzhbi', 10),
#  ('spotify:track:5KY7zgFeH2GWoL1zP9mME6', 9),
#  ('spotify:track:2q4rjDy9WhaN3o9MvDbO21', 9),
#  ('spotify:track:4tCtwWceOPWzenK2HAIJSb', 9),
#  ('spotify:track:1xznGGDReH1oQq0xzbwXa3', 9),
#  ('spotify:track:3H1LCvO3fVsK2HPguhbml0', 9),
#  ('spotify:track:1mr3616BzLdhXfJmLmRsO8', 9),
#  ('spotify:track:1D066zixBwqFYqBhKgdPzp', 9),
#  ('spotify:track:1hGy2eLcmC8eKx7qr1tOqx', 8),
#  ('spotify:track:7uKcScNXuO3MWw6LowBjW1', 8),
#  ('spotify:track:5i66xrvSh1MjjyDd6zcwgj', 8),
#  ('spotify:track:0OJXdyyVL8K6aovPgfqCcN', 8),
#  ('spotify:track:5OOkp4U9P9oL23maHFHL1h', 8),
#  ('spotify:track:69bp2EbF7Q2rqc5N3ylezZ', 8),
#  ('spotify:track:2CEgGE6aESpnmtfiZwYlbV', 8),
#  ('spotify:track:0CAfXk7DXMnon4gLudAp7J', 8),
#  ('spotify:track:27L8sESb3KR79asDUBu8nW', 8),
#  ('spotify:track:0Dc7J9VPV4eOInoxUiZrsL', 8),
#  ('spotify:track:2d8JP84HNLKhmd6IYOoupQ', 8),
#  ('spotify:track:4Kz4RdRCceaA9VgTqBhBfa', 8),
#  ('spotify:track:6C7RJEIUDqKkJRZVWdkfkH', 8),
#  ('spotify:track:3f7gYMirBEKuc57218BjOY', 8),
#  ('spotify:track:62LHRv9uwSNlBmByQF5jdE', 8),
#  ('spotify:track:7oK9VyNzrYvRFo7nQEYkWN', 8),
#  ('spotify:track:30VrBsh1STRBoIrhQOAwzK', 8),
#  ('spotify:track:0DdpxWfVvUGgkJv5536tiF', 8),
#  ('spotify:track:4bPQs0PHn4xbipzdPfn6du', 8),
#  ('spotify:track:3pfXxHoydFRfD7IBGJTQAN', 7),
#  ('spotify:track:6I9VzXrHxO9rA9A5euc8Ak', 7),
#  ('spotify:track:3S0OXQeoh0w6AY8WQVckRW', 7),
#  ('spotify:track:5lDriBxJd22IhOH9zTcFrV', 7),
#  ('spotify:track:5oQcOu1omDykbIPSdSQQNJ', 7),
#  ('spotify:track:4omisSlTk6Dsq2iQD7MA07', 7)]

# %%
train_playlists_dict, test_playlists_dict
# Out:
# ({4003:       pid  name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                             track_name                             track_uri             artist_name                             artist_uri                                 album_name                             album_uri  duration_ms
#   121  4003  HOLA         false   1493424000         104          89              2         20                              La Curita  spotify:track:1FJW4IKcJQXS897hxtLHhj                Aventura  spotify:artist:1qto4hHid1P71emI6Fd8xi                                   The Last  spotify:album:5kUva4uwVPMIyo8VX7pjBI       201266
#   117  4003  HOLA         false   1493424000         104          89              2         16                          Have Some Fun  spotify:track:5YNUvZm3tKAhzUcFlROTns                 Pitbull  spotify:artist:0TnOYISbd1XYRBk9myaseg  Global Warming: Meltdown (Deluxe Version)  spotify:album:2F7tejLHzTqFq2XLol9ZGy       244920
#   195  4003  HOLA         false   1493424000         104          89              2         94                            Shaky Shaky  spotify:track:58IL315gMSTD37DOZPJ2hf            Daddy Yankee  spotify:artist:4VMYDCV2IEDYJArk749S6m                                Shaky Shaky  spotify:album:2zrLk90b4qjmrxRZKyIY7X       234320
#   157  4003  HOLA         false   1493424000         104          89              2         56                       Reggaeton Latino  spotify:track:6Az6MyKCcshznWLxcREINf                Don Omar  spotify:artist:33ScadVnbm2X8kkUqOkC6Z                           Reggaeton Latino  spotify:album:52eNk8VLcj0QYzwjEyO2Hm       196920
#   149  4003  HOLA         false   1493424000         104          89              2         48  Pa Que Me Invitan - Spanglish Version  spotify:track:2VRssqds7rRNb4eaG9FaY8               Jencarlos  spotify:artist:3f4OfcNtgL9MLgiyOdIHC7                          Pa Que Me Invitan  spotify:album:2iXRXBgd81AHHL8vhrbmnN       234613
#   ..    ...   ...           ...          ...         ...         ...            ...        ...                                    ...                                   ...                     ...                                    ...                                        ...                                   ...          ...
#   167  4003  HOLA         false   1493424000         104          89              2         66                               La Chona  spotify:track:79xkyiTBHqdGg3SirACPwy  Los Tucanes De Tijuana  spotify:artist:014WIDx7H4BRCHB1faiisK             Para Tucancillos y Tucancillas  spotify:album:3oeX8Q7k6jH4Gq8WzRkNqb       199080
#   147  4003  HOLA         false   1493424000         104          89              2         46                              El Perdón  spotify:track:7qCAVkHWZkF44OzOUKf8Cr               Nicky Jam  spotify:artist:1SupJlEpv7RS2tPNRaHViT                                      Fénix  spotify:album:2dBgWXp41imu2zBNv9oFxZ       205906
#   150  4003  HOLA         false   1493424000         104          89              2         49                            La Charanga  spotify:track:1l6cp61AJPW71r3isZ6UBJ     Los Pumas Del Norte  spotify:artist:7oDAL6I6hsVHfn0ADFYpmh            Impresionantes Huellas Nortenas  spotify:album:0vlyMrJlRspc7LdG3zxUGB       229666
#   163  4003  HOLA         false   1493424000         104          89              2         62   Me Puedo Matar (feat. Hactor Acosta)  spotify:track:0LZQnaXoK56LjyLkTv2pKQ         Bachata Heightz  spotify:artist:5zvRX0y0JYtGOmGJwLwyIL                             La Mega Mezcla  spotify:album:5vysmao1LqnKFihfi7SBXD       264853
#   170  4003  HOLA         false   1493424000         104          89              2         69                        Payaso de Rodeo  spotify:track:0EVcfyLGhkvm2RMXMWI456          Caballo Dorado  spotify:artist:38yOUctO9eek9ti5NWMQXm                            Payaso de rodeo  spotify:album:1NMqmkX9KhLoy5fXxtiS5S       254666
#
#   [72 rows x 15 columns],
#   4129:        pid  name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                        track_name                             track_uri                              artist_name                             artist_uri                                 album_name                             album_uri  duration_ms
#   8911  4129  calm         false   1494288000         117          96              1         58                           Tornado  spotify:track:5l1w4a1ETkNaSM2h37Mp4x                                    Jónsi  spotify:artist:3khg8RDB6nMuw34w1IHS6Y                                         Go  spotify:album:1fgtiyeUDIoUayYbwroqVH       254973
#   8893  4129  calm         false   1494288000         117          96              1         40                       Home By Now  spotify:track:4vd5POsDm1JblJT9ZpYM5L                      Bombay Bicycle Club  spotify:artist:3pTE9iaJTkWns3mxpNQlJV                  So Long, See You Tomorrow  spotify:album:5oKWoolIuoWMG6AORvA9hL       274653
#   8942  4129  calm         false   1494288000         117          96              1         89                     Poison & Wine  spotify:track:0Z9TbLIhMAXa8BSOiY6um6                           The Civil Wars  spotify:artist:6J7rw7NELJUCThPbAfyLIE                              Barton Hollow  spotify:album:6tQjO7LXVL6byHa0ZF4emD       219440
#   8944  4129  calm         false   1494288000         117          96              1         91           Dust to Dust - Acoustic  spotify:track:2P84QNQFhSoexVt5jEsfmd                           The Civil Wars  spotify:artist:6J7rw7NELJUCThPbAfyLIE                              Bare Bones EP  spotify:album:0EIZbhrZvPpSoR0JnqvjWn       223786
#   8857  4129  calm         false   1494288000         117          96              1          4                        My Sundown  spotify:track:4S2hwCTt7F6QusyrYYparO                          Jimmy Eat World  spotify:artist:3Ayl7mCk0nScecqOzvNp6s                             Bleed American  spotify:album:1VbyDS3tGhe4iHfIJ7AMtr       347866
#   ...    ...   ...           ...          ...         ...         ...            ...        ...                               ...                                   ...                                      ...                                    ...                                        ...                                   ...          ...
#   8933  4129  calm         false   1494288000         117          96              1         80                          Equation  spotify:track:2MppombzTgsEn5AKt8UfpE                                  Camille  spotify:artist:0gOsZcHl7H3ewXVIEnWFZX  Le Petit Prince (Bande originale du film)  spotify:album:61xHE9mlaQK7Pn02Qr3Scy       123746
#   8940  4129  calm         false   1494288000         117          96              1         87                   My Lady's House  spotify:track:38yRRKLWBBlX2UFt95a2U8                              Iron & Wine  spotify:artist:4M5nCE77Qaxayuhp3fVn4V                                 Woman King  spotify:album:7oc83zmuY0ODfp8K478lHi       212840
#   8903  4129  calm         false   1494288000         117          96              1         50  Mushaboom - Postal Service Remix  spotify:track:7skhJDLp2v8ihSOLthRWl1                                    Feist  spotify:artist:6CWTBjOJK75cTE8Xv8u1kj                                Open Season  spotify:album:5z5qxQggmOBwSDjTOy77L6       213160
#   8946  4129  calm         false   1494288000         117          96              1         93                         Architect  spotify:track:4WUVwGvscAM2nXbENtQHSY  Manchester Orchestra, Frightened Rabbit  spotify:artist:1RYQrEayemDWfe8Ap0D5Og                                  Architect  spotify:album:30XRmWTdvcHHMUEVTB8aIL       234051
#   8955  4129  calm         false   1494288000         117          96              1        102               Looking Too Closely  spotify:track:3kYLXiKj14M0YkX32YqqWs                                     Fink  spotify:artist:2t9yJDJIEtvPmr2iRIdqBf                              Hard Believer  spotify:album:1JjDBgP1sLf7Tmb7fwJLnE       310693
#
#   [81 rows x 15 columns],
#   4130:        pid  name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos               track_name                             track_uri      artist_name                             artist_uri                          album_name                             album_uri  duration_ms
#   9053  4130  Elec         false   1492041600         177          64              1         83            Tacobel Canon  spotify:track:6Bn8QuwLkcAOaJ6R25NfaF          Ratatat  spotify:artist:57dN52uHvrHOxijzpIgu3E                            Classics  spotify:album:2n5wpk7KaHpp3mgUYqpF4f       266760
#   8989  4130  Elec         false   1492041600         177          64              1         19                  Da Funk  spotify:track:0MyY4WcN7DIfbSmp5yej5z        Daft Punk  spotify:artist:4tZwfgrHOc3mvqYlEYSvVi                            Homework  spotify:album:5uRdvUR7xCnHmUW8n64n9y       328680
#   9136  4130  Elec         false   1492041600         177          64              1        166                     Eple  spotify:track:0Zw4llKeB35SIKASy1aLtV         Röyksopp  spotify:artist:5nPOO9iTcrs9k6yFffPxjH                           Melody AM  spotify:album:1WHbPhjPCBhjo49DpKvYbL       218320
#   9106  4130  Elec         false   1492041600         177          64              1        136           A Higher Place  spotify:track:1faWHSAuHunRZRoH2ujmND         Röyksopp  spotify:artist:5nPOO9iTcrs9k6yFffPxjH                           Melody AM  spotify:album:1WHbPhjPCBhjo49DpKvYbL       271200
#   9084  4130  Elec         false   1492041600         177          64              1        114                     Slip  spotify:track:6jn8hd5UABzdI9pLAYsOrp         Autechre  spotify:artist:6WH1V41LwGDGmlPUhSZLHO                               Amber  spotify:album:487Dko0WyRBpfiZWOrurYu       381106
#   ...    ...   ...           ...          ...         ...         ...            ...        ...                      ...                                   ...              ...                                    ...                                 ...                                   ...          ...
#   9069  4130  Elec         false   1492041600         177          64              1         99                  No Eyes  spotify:track:0Yi9s1AmrWN9cpx92T95Ln            Baths  spotify:artist:5zS8r5hRRk1jzD41yYS1NO                            Obsidian  spotify:album:6R0fwFVFR5lmrvDlSYLC1b       253666
#   9108  4130  Elec         false   1492041600         177          64              1        138     Acrid Avid Jam Shred  spotify:track:3Bp478Itxv8gxqqEcf8HRL       Aphex Twin  spotify:artist:6kBDZFXuLrZgHnvmPu9NsG            ...I Care Because You Do  spotify:album:0VG7XLJ8gSynEQDVnpHNNU       459280
#   9024  4130  Elec         false   1492041600         177          64              1         54       Dance Yrself Clean  spotify:track:2cmRpmO04TLaKPzmAzySYZ  LCD Soundsystem  spotify:artist:066X20Nz7iquqkkCW6Jxy6                   This Is Happening  spotify:album:4hnqM0JK4CM1phwfq1Ldyz       536471
#   9001  4130  Elec         false   1492041600         177          64              1         31  A Pain That I'm Used To  spotify:track:2G2PdkATB8EADrjHhXQuPP     Depeche Mode  spotify:artist:762310PdDnwsDxAQxzQkfX  Playing the Angel (Deluxe Version)  spotify:album:57o8ROknLhGAxhiLKTOwSt       250893
#   9135  4130  Elec         false   1492041600         177          64              1        165                  So Easy  spotify:track:0rOaRWuB9sml2q60FuB0I8         Röyksopp  spotify:artist:5nPOO9iTcrs9k6yFffPxjH                           Melody AM  spotify:album:1WHbPhjPCBhjo49DpKvYbL       249360
#
#   [123 rows x 15 columns],
#   4131:        pid name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                                         track_name                             track_uri   artist_name                             artist_uri           album_name                             album_uri  duration_ms
#   9167  4131   🎉🎉         false   1497398400         148         113              4         20  Hey Mama (feat. Nicki Minaj, Bebe Rexha & Afro...  spotify:track:285HeuLxsngjFn4GGegGNm  David Guetta  spotify:artist:1Cs0zKBU1kc0i8ypK3B9ai               Listen  spotify:album:77UW17CZFyCaRLHdHeofZu       192560
#   9244  4131   🎉🎉         false   1497398400         148         113              4         97                                          Controlla  spotify:track:6F609ICg9Spjrw1epsAnpa         Drake  spotify:artist:3TVXtAsR1Inumwj472S9r4                Views  spotify:album:3hARKC8cinq3mZLLAEaBh9       245226
#   9150  4131   🎉🎉         false   1497398400         148         113              4          3                                            Titanic  spotify:track:1E86g8l5yVwTyoGR7u6odv    Steve Aoki  spotify:artist:77AiFEVeAVj2ORpC85QVJs  Neon Future Odyssey  spotify:album:1jCnqnJdjCvP3XvbQttVTK       322500
#   9160  4131   🎉🎉         false   1497398400         148         113              4         13                                    Runaway (U & I)  spotify:track:46lFttIf5hnUZMGvjK0Wxo      Galantis  spotify:artist:4sTQVOfp9vEMCemLw50sbu             Pharmacy  spotify:album:4QcXq4vTVN7dFb7bZa9jG2       227073
#   9152  4131   🎉🎉         false   1497398400         148         113              4          5                        Lit (feat. Curtis Williams)  spotify:track:4zMghHHGQDsL9KYhKQWGpX      LOUDPVCK  spotify:artist:0rQ0WMIrOt6MzfiGaNWh3D                  Lit  spotify:album:52bIQiWinQ9zjK8Aus41BR       222394
#   ...    ...  ...           ...          ...         ...         ...            ...        ...                                                ...                                   ...           ...                                    ...                  ...                                   ...          ...
#   9282  4131   🎉🎉         false   1497398400         148         113              4        135                         Bonbon - Post Malone Remix  spotify:track:6wtVhb7nEcZ1f0iMOF9mlT   Era Istrefi  spotify:artist:4poL7YCSkG7kMnWjAdDU91            Bonbon EP  spotify:album:7uUXD2hyJv90V9syhXfrX6       202368
#   9261  4131   🎉🎉         false   1497398400         148         113              4        114                        Fine Ass Mess - Conro Remix  spotify:track:4nOnjlF5M0neE1U0nQ9OMz     Mr. Probz  spotify:artist:33W1pnW9zScZtYTnAoWnOT        Fine Ass Mess  spotify:album:7MwBBBsdKYm9dpu0m9mlTm       203252
#   9290  4131   🎉🎉         false   1497398400         148         113              4        143                                          My Number  spotify:track:2MtVRrJhnWtPBSaszRPV2B   Major Lazer  spotify:artist:738wLrAtLtCtFOLvQBXOXp            My Number  spotify:album:0Nybjecn1QeljznWb1gioB       198728
#   9277  4131   🎉🎉         false   1497398400         148         113              4        130                                       Vente Pa' Ca  spotify:track:7DM4BPaS7uofFul3ywMe46  Ricky Martin  spotify:artist:7slfeZO9LsJbWgpkIoXBUJ         Vente Pa' Ca  spotify:album:1FkaJUwfqLdQdSmRPBlw6l       259195
#   9196  4131   🎉🎉         false   1497398400         148         113              4         49                         The Hills - RL Grime Remix  spotify:track:4jmfX9D0GoHnkSGDwPN7HB    The Weeknd  spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ            The Hills  spotify:album:2A7d4WOv1L9Nv3zQTKXkQ5       271066
#
#   [103 rows x 15 columns],
#   4133:        pid          name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos        track_name                             track_uri       artist_name                             artist_uri       album_name                             album_uri  duration_ms
#   9371  4133  SWEET SUMMER         false   1441843200         131          90              1         69         Two Weeks  spotify:track:2UYJqglnOMTvRcqQLNcjjf         FKA twigs  spotify:artist:6nB0iY1cjSY1KyhYyuIIKH              LP1  spotify:album:4in34qwyUghNc9ykmH2BTO       247547
#   9302  4133  SWEET SUMMER         false   1441843200         131          90              1          0     Electric Love  spotify:track:2GiJYvgVaD2HtM8GqD9EgQ             BØRNS  spotify:artist:1KP6TWI40m7p3QBTU6u2xo         Dopamine  spotify:album:17l7MIu0Jh0tdgK7or9ovw       218106
#   9429  4133  SWEET SUMMER         false   1441843200         131          90              1        127        Come Close  spotify:track:2dCD8qq7yHZPZduA8FJazs            Common  spotify:artist:2GHclqNVjqGuiE5mA7BEoc  Electric Circus  spotify:album:4eD2SoySMPRl0SBv7rqk1X       275066
#   9430  4133  SWEET SUMMER         false   1441843200         131          90              1        128     Break You Off  spotify:track:4jZcfHe0hbc5ireJAxmQvC         The Roots  spotify:artist:78xUyw6FkVZrRAtziFdtdu       Phrenology  spotify:album:4rKiBz8pX9zmKuEk4NArfm       447440
#   9386  4133  SWEET SUMMER         false   1441843200         131          90              1         84      Magic Chords  spotify:track:3cI9kNRxlpYYuCAEbP91My  Sharon Van Etten  spotify:artist:2wJ4vsxWd7df7dRU4KcoDe            Tramp  spotify:album:7bYAuBOpWMA1F61cbXrKfM       236173
#   ...    ...           ...           ...          ...         ...         ...            ...        ...               ...                                   ...               ...                                    ...              ...                                   ...          ...
#   9389  4133  SWEET SUMMER         false   1441843200         131          90              1         87    Summer Of Love  spotify:track:0Dn9lj5PCHmippXUg4LMz4       Waxahatchee  spotify:artist:5IWCU0V9evBlW4gIeGY4zF        Ivy Tripp  spotify:album:330rzJqNOw2BELsfWg3vXl       140760
#   9308  4133  SWEET SUMMER         false   1441843200         131          90              1          6          Ratcliff  spotify:track:1StpNFBn01BsdbSXbA2VrI        Toro y Moi  spotify:artist:6O4EGCCb6DoIiR6B1QCQgp        What For?  spotify:album:5IFt4HfQU8t336zryKaAyr       161445
#   9343  4133  SWEET SUMMER         false   1441843200         131          90              1         41          Hey Life  spotify:track:3A0uhh9AOnTYNfe1jYoyEA        Tune-Yards  spotify:artist:0asVlqTLu3TimnYVyY5Jxi       nikki nack  spotify:album:1qfQJDGIBDJ3Wis7ILOXAK       217333
#   9383  4133  SWEET SUMMER         false   1441843200         131          90              1         81          Our Love  spotify:track:515P0lF6EJ66lbgspIPGTL  Sharon Van Etten  spotify:artist:2wJ4vsxWd7df7dRU4KcoDe     Are We There  spotify:album:4KbSTaPVbyQIWQGNL8Uqmx       232760
#   9336  4133  SWEET SUMMER         false   1441843200         131          90              1         34  Yes I'm Changing  spotify:track:0xtIp0lgccN85GfGOekS5L       Tame Impala  spotify:artist:5INjqkS1o8h1imAzPqGZBb         Currents  spotify:album:79dL7FLiJFOO0EoehUHQBv       270680
#
#   [91 rows x 15 columns],
#   4138:        pid  name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                                         track_name                             track_uri              artist_name                             artist_uri              album_name                             album_uri  duration_ms
#   9748  4138  JAMZ         false   1378684800          90          81              1         82                                     Clint Eastwood  spotify:track:7yMiX7n9SBvadzox8T5jzT                 Gorillaz  spotify:artist:3AA28KZvwAUcZuOKwyblJQ                Gorillaz  spotify:album:0YvYmLBFFwYxgI4U9KKgUm       340920
#   9736  4138  JAMZ         false   1378684800          90          81              1         70                             The Start Of Something  spotify:track:6K5GAopLZzzg0ZX8k5GWwh                  Voxtrot  spotify:artist:7b697TI9p2abLzSo3eJTKW     Raised By Wolves EP  spotify:album:6Le1FSqseZp41WAub4Ct4v       271746
#   9740  4138  JAMZ         false   1378684800          90          81              1         74                                             Closer  spotify:track:4dTVgHZFPlaq9nPbLVVLSG           Tegan and Sara  spotify:artist:5e1BZulIiYWPRm8yogwUYH              Heartthrob  spotify:album:5IUJ6v408Z7pECC3BXUJxX       209280
#   9751  4138  JAMZ         false   1378684800          90          81              1         85                                       Miracle Mile  spotify:track:4RvmQ5qbP5PxgJD0BN4EZK            Cold War Kids  spotify:artist:6VDdCwrBM4qQaGxoAyxyJC  Dear Miss Lonelyhearts  spotify:album:3InEURs5PQ2CMrnvzSVaPy       180133
#   9672  4138  JAMZ         false   1378684800          90          81              1          6  One Day / Reckoning Song (Wankelmut Remix) [Ra...  spotify:track:1FBeSZBuAZvnF8eCbixeNs  Asaf Avidan & the Mojos  spotify:artist:2TwepUY7feaTuipStcyzLZ           The Reckoning  spotify:album:6S3ZHdLQRkuknoivj0xS8e       213186
#   ...    ...   ...           ...          ...         ...         ...            ...        ...                                                ...                                   ...                      ...                                    ...                     ...                                   ...          ...
#   9734  4138  JAMZ         false   1378684800          90          81              1         68                                     Two Doors Down  spotify:track:5JSF5Nhw9W6j9qt74rYTa7             Mystery Jets  spotify:artist:09K1H1DgyIXHsMx2j7KTFX              Twenty One  spotify:album:2efbbdHh1iSps9yfBZdy7G       219013
#   9702  4138  JAMZ         false   1378684800          90          81              1         36                                        Ride Wit Me  spotify:track:06iMqWThw4w8fTFyccvOwr                    Nelly  spotify:artist:2gBjLmx6zQnFGQJCAQpRgw         Country Grammar  spotify:album:2HWBPvQoaMFBF6krXyzpOv       291781
#   9689  4138  JAMZ         false   1378684800          90          81              1         23                                He Doesn't Know Why  spotify:track:4FlNj8oEuikVspfVWzMZVz              Fleet Foxes  spotify:artist:4EVpmkEwrLYEg6jIsiPMIb             Fleet Foxes  spotify:album:1rfgmU0AYNwWfS88pCOlX7       200493
#   9684  4138  JAMZ         false   1378684800          90          81              1         18                Rich Girls - Explicit Album Version  spotify:track:4KWUVilgHxC10fi3yMxtMQ              The Virgins  spotify:artist:6RNuLHIAlLt1FQHm03oEru             The Virgins  spotify:album:0LGpPtKVoDRnKJGjnUJBLd       182093
#   9683  4138  JAMZ         false   1378684800          90          81              1         17                                 One Week Of Danger  spotify:track:5ubLf5KrEIn109OYEJDo0e              The Virgins  spotify:artist:6RNuLHIAlLt1FQHm03oEru             The Virgins  spotify:album:0LGpPtKVoDRnKJGjnUJBLd       164493
#
#   [63 rows x 15 columns],
#   4175:         pid  name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                                         track_name                             track_uri              artist_name                             artist_uri                              album_name                             album_uri  duration_ms
#   12810  4175  tbt.         false   1487808000         189         150              3        100  I Got Nerve - From "Hannah Montana"/Soundtrack...  spotify:track:3bSq5OpEWmLK1o8F7saR2F           Hannah Montana  spotify:artist:7nU4hB040gTmHm45YYMvqc                          Hannah Montana  spotify:album:0TyDqWrWHzuyFjjnKqDClu       184226
#   12782  4175  tbt.         false   1487808000         189         150              3         72                 Push It (Re-Recorded) [Remastered]  spotify:track:7iVsgWjc037KNS1L1zKES7              Salt-N-Pepa  spotify:artist:7wqtxqI3eo7Gn1P7SpP6cQ                           Greatest Hits  spotify:album:2AQGzqUAlpD1fiWSkmorKU       273398
#   12863  4175  tbt.         false   1487808000         189         150              3        153                                    Banana Smoothie  spotify:track:3AZibYfqVAdBAldsP9wKy9  The Naked Brothers Band  spotify:artist:2qi6i5kIHHeEszXyQT7VJb                 The Naked Brothers Band  spotify:album:0P0hiVXmXvn0HwkCKECqQS       152906
#   12799  4175  tbt.         false   1487808000         189         150              3         89                              Best Friend's Brother  spotify:track:0VRh0HgB1RsgqjH7YswsJK          Victorious Cast  spotify:artist:1KYszkVzlhV3rAqmAcYIgd  Victorious: Music From The Hit TV Show  spotify:album:39Mc1rLpJeiG5BYuSOwGet       218266
#   12895  4175  tbt.         false   1487808000         189         150              3        185                                        Want U Back  spotify:track:5InWRmnfgjVwQWoXHNBATu               Cher Lloyd  spotify:artist:4m4SfDVbF5wxrwEjDKgi4k                         Sticks & Stones  spotify:album:0z5qKyh9ys3kk9oLEzgG5l       214013
#   ...     ...   ...           ...          ...         ...         ...            ...        ...                                                ...                                   ...                      ...                                    ...                                     ...                                   ...          ...
#   12752  4175  tbt.         false   1487808000         189         150              3         42                                           Survivor  spotify:track:7qtAgn9mwxygsPOsUDVRRt          Destiny's Child  spotify:artist:1Y8cdNmUJH7yBTd9yOvr5i                                Survivor  spotify:album:0IVseR3zfrrInlKJQNh294       254040
#   12875  4175  tbt.         false   1487808000         189         150              3        165                              Chemicals React Remix  spotify:track:7vOjTY220BqIttYDbwshED                 Aly & AJ  spotify:artist:5wugb0kaq0J6nyQ5Xgd17i                             Insomniatic  spotify:album:4TOOGDpJ9KQ8EM84TC4qj6       175920
#   12892  4175  tbt.         false   1487808000         189         150              3        182                                              Vogue  spotify:track:7j5TIXPi0cCbSSqItmbyZy                  Madonna  spotify:artist:6tbjWDEIzxoDsBA1FuhfPW               The Immaculate Collection  spotify:album:5MzwGwnO9gkh0z6Nl4FF8h       317080
#   12754  4175  tbt.         false   1487808000         189         150              3         44                              Run the World (Girls)  spotify:track:1uXbwHHfgsXcUKfSZw5ZJ0                  Beyoncé  spotify:artist:6vWDO969PvNqNYHIOW5v0m                                       4  spotify:album:1gIC63gC3B7o7FfpPACZQJ       236093
#   12744  4175  tbt.         false   1487808000         189         150              3         34                            Dear Maria, Count Me In  spotify:track:0J69x3mqm7U6tBPKsjpsWR             All Time Low  spotify:artist:46gyXjRIvN1NL1eCB8GBxo                    So Wrong, It's Right  spotify:album:7GcuimRczCCOblhJr0NgzD       182826
#
#   [132 rows x 15 columns],
#   4179:         pid   name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                               track_name                             track_uri              artist_name                             artist_uri                        album_name                             album_uri  duration_ms
#   13026  4179  Chill         false   1500336000          91          76              1         23                                   Animal  spotify:track:1uxdxSC2bfUFYVqxvejVC3               Miike Snow  spotify:artist:4l1cKWYW591xnwEGxpUg3J                        Miike Snow  spotify:album:60qoUhwjHanuH4uO7ik4r5       263426
#   13085  4179  Chill         false   1500336000          91          76              1         82    (What A) Wonderful World - Remastered  spotify:track:27K3ZDS5B4fwjhwyihrdzC                Sam Cooke  spotify:artist:6hnWRPzGGKiapVX1UCdEAC  The Wonderful World Of Sam Cooke  spotify:album:4y3NeFX7yaEzQfxy70NhZ3       125506
#   13049  4179  Chill         false   1500336000          91          76              1         46                                   Boston  spotify:track:2WZyfujzMweFLnozyUJBkW                Augustana  spotify:artist:61YE3whKiuRr83j1yOm5M7      All The Stars and Boulevards  spotify:album:36i3fUi7xuuE0UA8pXtdxK       245933
#   13023  4179  Chill         false   1500336000          91          76              1         20                                   Afraid  spotify:track:7brQHA2CgQpcMBiOlfiXYb        The Neighbourhood  spotify:artist:77SW9BnxLY8rJ0RciFqkHh                       I Love You.  spotify:album:4xkM0BwLM9H2IUcbYzpcBI       251186
#   13054  4179  Chill         false   1500336000          91          76              1         51                          Pictures Of You  spotify:track:4bfyeYgNLENrwLRRSKXfM3       The Last Goodnight  spotify:artist:4UrGiQXrpB2CmzVGVFtH5E                       Poison Kiss  spotify:album:3MOMO36PjOCsTjRgN7D7IE       189933
#   ...     ...    ...           ...          ...         ...         ...            ...        ...                                      ...                                   ...                      ...                                    ...                               ...                                   ...          ...
#   13009  4179  Chill         false   1500336000          91          76              1          6                               Other Ways  spotify:track:6TPuL0IRzvOypCzd3cPuUc              Trevor Hall  spotify:artist:3RMHexittaAZkf8zukkZB8                        Other Ways  spotify:album:2zMTzTByvOYjjR5Sjpe0ZW       204973
#   13056  4179  Chill         false   1500336000          91          76              1         53                          Sooner Or Later  spotify:track:52FF0XmKQcTkeRrPihou94              Mat Kearney  spotify:artist:2NQEwAVHBNcI0tGMLlWwF1                        Young Love  spotify:album:2ZWWgHg97ZzJpWz80LUTQA       236440
#   13044  4179  Chill         false   1500336000          91          76              1         41             California - Tchad Blake Mix  spotify:track:497Fkp3gRiGrRMoqBTDudr           Phantom Planet  spotify:artist:0LsTFjEB1IIrh7IlTxs1GY                         The Guest  spotify:album:4SvTjA2cwASS1cWzEIG0WD       193933
#   13032  4179  Chill         false   1500336000          91          76              1         29  White Walls (feat. ScHoolboy Q, Hollis)  spotify:track:3TKt9EoDMmKvNYpk1e6GkI  Macklemore & Ryan Lewis  spotify:artist:5BcAKTbp20cv7tC5VqPFoC        The Heist [Deluxe Edition]  spotify:album:0CoiTAUBiO70lic9p9Lboq       220319
#   13007  4179  Chill         false   1500336000          91          76              1          4                          Do You Remember  spotify:track:1EZJBB6bvCcrvYRlOyoHuf             Jack Johnson  spotify:artist:3GBPw9NK25X1Wt2OUvOwY3                 In Between Dreams  spotify:album:7tTc46dNdE6GGuiQsssWxo       144013
#
#   [63 rows x 15 columns],
#   4191:         pid    name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                             track_name                             track_uri                   artist_name                             artist_uri                             album_name                             album_uri  duration_ms
#   13851  4191  party          false   1479600000         151         123              3         44                              Rack City  spotify:track:0srwKuJPH8yBzzFUJMBQM2                          Tyga  spotify:artist:5LHRHt1k9lMyONurDHEdrp  Careless World: Rise Of The Last King  spotify:album:3KHamR7LZmFT0xqPA1Hyob       203200
#   13877  4191  party          false   1479600000         151         123              3         70                         Look At Me Now  spotify:track:0LWQWOFoz5GJLqcHk1fRO2                   Chris Brown  spotify:artist:7bXgB6jMjp9ATFy66eO08Z                               F.A.M.E.  spotify:album:6rEm9wAyZP79RFa2qW2bf7       222586
#   13914  4191  party          false   1479600000         151         123              3        107                               My Nigga  spotify:track:27PmKcvsjXp7G1IQgLUkYY                            YG  spotify:artist:0A0FS04o6zMoto8OKPsDwY                          My Krazy Life  spotify:album:6cW84YyjHToN3qqBwKDKQX       235600
#   13891  4191  party          false   1479600000         151         123              3         84                       Get Low - Street  spotify:track:5KY7zgFeH2GWoL1zP9mME6  Lil Jon & The East Side Boyz  spotify:artist:3ciRvbBIVz9fBoPbtSYq4x                         Kings Of Crunk  spotify:album:3JMQJnoGhwnwAwLGuJAUEJ       334093
#   13832  4191  party          false   1479600000         151         123              3         25                                Ti**ies  spotify:track:7bOsLxLmt2sIvRGx8DKdA9                  Krizz Kaliko  spotify:artist:3SEJQy90Vgg1aSnZ9b4AU9            Son of Sam (Deluxe Edition)  spotify:album:53VCouDZUSlltXH2yMZ7Bx       228520
#   ...     ...     ...           ...          ...         ...         ...            ...        ...                                    ...                                   ...                           ...                                    ...                                    ...                                   ...          ...
#   13954  4191  party          false   1479600000         151         123              3        147             Bitch Better Have My Money  spotify:track:5lnsCyEKWofnC00U4Ax0ti                       Rihanna  spotify:artist:5pKCCKE2ajJHZ9KAiaK11H             Bitch Better Have My Money  spotify:album:0L6tzOdcRwb82xMBZ3WZyi       219305
#   13896  4191  party          false   1479600000         151         123              3         89                              Kiss Kiss  spotify:track:47x1F4HyX7LafFgxtoa19P                   Chris Brown  spotify:artist:7bXgB6jMjp9ATFy66eO08Z        Exclusive - The Forever Edition  spotify:album:1UtE4zAlSE2TlKmTFgrTg5       250666
#   13894  4191  party          false   1479600000         151         123              3         87                        Outta Your Mind  spotify:track:1Oenqmtbzt331Pgv0ODfS2                       Lil Jon  spotify:artist:7sfl4Xt5KmfyDs2T3SVSMK                             Crunk Rock  spotify:album:49qpwRDGLfNAkUG9UeGoTV       250746
#   13903  4191  party          false   1479600000         151         123              3         96  Work - BURNS' Late Night Rollin Remix  spotify:track:4dIzTxae4X42liwDvwBso7                       Rihanna  spotify:artist:5pKCCKE2ajJHZ9KAiaK11H                                   Work  spotify:album:5xLUp4nUTuXNK7XKQPE5Gb       222546
#   13870  4191  party          false   1479600000         151         123              3         63                                 Forbes  spotify:track:31RYcUDhkqkH1W2xxnzBjY                        G-Eazy  spotify:artist:02kJSzxNuaWGqwubyUba0Z                                 Forbes  spotify:album:49vSoDFKeJoXe1Nxy20k0s       206315
#
#   [105 rows x 15 columns],
#   4226:         pid      name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                  track_name                             track_uri          artist_name                             artist_uri               album_name                             album_uri  duration_ms
#   15798  4226  my jams          false   1500681600         135          88              1        119  The Other Side Of Paradise  spotify:track:0rRjGruFonCGOt0S5zAJNQ        Glass Animals  spotify:artist:4yvcSjfu4PC0CYQyLy4wSq  How To Be A Human Being  spotify:album:6qb9MDR0lfsN9a2pw77uJy       320654
#   15690  4226  my jams          false   1500681600         135          88              1         11                    Lane Boy  spotify:track:2P61EK6DMGyVyssLWS4fKy    Twenty One Pilots  spotify:artist:3YQKmKGau1PzlVlkL1iodx               Blurryface  spotify:album:3cQO7jp5S9qLBoIVtbkSM1       253093
#   15748  4226  my jams          false   1500681600         135          88              1         69         Tell Me How To Feel  spotify:track:7uF3yM2MZnK6X3PaYywpLN                 Lido  spotify:artist:1aSwrSGBNGMLn9ymttfRkk               Everything  spotify:album:6dEE2Uq1BNDmZg5lGuH0gU       328384
#   15778  4226  my jams          false   1500681600         135          88              1         99              So Here We Are  spotify:track:2gQsPR9lIBz7ZGigtPVKgg                Gordi  spotify:artist:6UBMFaCTZnL1Hr1nTOEblM       Clever Disguise EP  spotify:album:2ljSy3fQIqvR06AMkA8Exd       248876
#   15751  4226  my jams          false   1500681600         135          88              1         72     The Ballad Of Mona Lisa  spotify:track:5rLi8B8qgk6qThwRnKHW2P  Panic! At The Disco  spotify:artist:20JZFwl6HVl6yg8a4H3ZqK          Vices & Virtues  spotify:album:5S0nsfYhHa1uz10V4yoWSL       226680
#   ...     ...       ...           ...          ...         ...         ...            ...        ...                         ...                                   ...                  ...                                    ...                      ...                                   ...          ...
#   15698  4226  my jams          false   1500681600         135          88              1         19           House Of Memories  spotify:track:2DgdHcjWmO3qd50RzuBLgZ  Panic! At The Disco  spotify:artist:20JZFwl6HVl6yg8a4H3ZqK      Death Of A Bachelor  spotify:album:6twKQ0EsUJHVlAr6XBylrj       208706
#   15785  4226  my jams          false   1500681600         135          88              1        106                  ocean eyes  spotify:track:3OMh7VdOoWgtKhJimQQywz        Billie Eilish  spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH         dont smile at me  spotify:album:07WV4Vf6503k6K1yGNWG8X       200379
#   15795  4226  my jams          false   1500681600         135          88              1        116   Lane Boy (feat. MUTEMATH)  spotify:track:3bOfawOrDpk59qq9iuvJdw    Twenty One Pilots  spotify:artist:3YQKmKGau1PzlVlkL1iodx                   TOPxMM  spotify:album:1UIKUO8x3xAkQBnJghN41m       321000
#   15696  4226  my jams          false   1500681600         135          88              1         17                    Cry Baby  spotify:track:0EfsDEYaSjGYd66Pr881nq    The Neighbourhood  spotify:artist:77SW9BnxLY8rJ0RciFqkHh               Wiped Out!  spotify:album:18iFxjZugvKhuNNMbLjZJF       235160
#   15797  4226  my jams          false   1500681600         135          88              1        118            Baby Eyes - Demo  spotify:track:2wBXASKIIkUPjHn0n8nfrY            Green Day  spotify:artist:7oPftvlwr6VrsViSDV7fJY              Demolicious  spotify:album:7prfPBMbgDyhq7kdpM0R9v       135000
#
#   [94 rows x 15 columns],
#   4296:         pid   name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                    track_name                             track_uri   artist_name                             artist_uri                 album_name                             album_uri  duration_ms
#   20248  4296  chill         false   1508544000         111          79              2         62                       Go Flex  spotify:track:5yuShbu70mtHXY0yLzCQLQ   Post Malone  spotify:artist:246dkjvS1zLTtiykXe5h60                     Stoney  spotify:album:5s0rmjP8XOPhP6HhqOhuyC       179613
#   20261  4296  chill         false   1508544000         111          79              2         75                 XO TOUR Llif3  spotify:track:7GX5flRQZVHRAGd6B4TmDO  Lil Uzi Vert  spotify:artist:4O15NlyKLIASxsJ0PrXPfz              Luv Is Rage 2  spotify:album:733e1ZfktLSwj96X5rsMeE       182706
#   20249  4296  chill         false   1508544000         111          79              2         63                 Tunnel Vision  spotify:track:4Q3N4Ct4zCuIHuZ65E3BD4   Kodak Black  spotify:artist:46SHBwWsqBkxI7EeeBEQG7          Painting Pictures  spotify:album:5mG8oNkNKM2my7t9ywra96       268186
#   20186  4296  chill         false   1508544000         111          79              2          0                Black Skinhead  spotify:track:722tgOgdIbNe3BEyLnejw4    Kanye West  spotify:artist:5K4W6rqBFWDnAN6FQUkS6x                     Yeezus  spotify:album:7D2NdGvBHIavgLhmcwhluK       188013
#   20200  4296  chill         false   1508544000         111          79              2         14  Facts (Charlie Heat Version)  spotify:track:3MnbXlC1N7GdS9M8HzA6no    Kanye West  spotify:artist:5K4W6rqBFWDnAN6FQUkS6x          The Life Of Pablo  spotify:album:7gsWAHLeT0w7es6FofOXk1       200733
#   ...     ...    ...           ...          ...         ...         ...            ...        ...                           ...                                   ...           ...                                    ...                        ...                                   ...          ...
#   20199  4296  chill         false   1508544000         111          79              2         13                          Fade  spotify:track:3cCxoOgfi6hgt8MNteuiiD    Kanye West  spotify:artist:5K4W6rqBFWDnAN6FQUkS6x          The Life Of Pablo  spotify:album:7gsWAHLeT0w7es6FofOXk1       193747
#   20206  4296  chill         false   1508544000         111          79              2         20                 Touch The Sky  spotify:track:6mxyfdyF4LD7PctU3UNyjF    Kanye West  spotify:artist:5K4W6rqBFWDnAN6FQUkS6x          Late Registration  spotify:album:4GRDFQ9HRoO0by8H0r2a3I       236600
#   20222  4296  chill         false   1508544000         111          79              2         36                      Low Life  spotify:track:7EiZI6JVHllARrX9PUvAdX        Future  spotify:artist:1RyvyyTE3xzB2ZywiAwp0i                       EVOL  spotify:album:3jJKDKdlwRS584zUlHV2Ly       313546
#   20208  4296  chill         false   1508544000         111          79              2         22                     Pop Style  spotify:track:5mPSyjLatqB00IkPqRlbTE         Drake  spotify:artist:3TVXtAsR1Inumwj472S9r4                      Views  spotify:album:40GMAhriYJRO1rsY4YdrZb       212946
#   20219  4296  chill         false   1508544000         111          79              2         33                   Young Jesus  spotify:track:0KiKfllNTmhImvXVIHqR0z         Logic  spotify:artist:4xRYI6VqpkE3UwrDrAZL8L  The Incredible True Story  spotify:album:5dOpbgAmJeyoakKQ0QLWkR       211573
#
#   [77 rows x 15 columns],
#   4367:         pid   name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                    track_name                             track_uri             artist_name                             artist_uri               album_name                             album_uri  duration_ms
#   25122  4367  Vibes         false   1509408000         132         113              1        127  Drowning (feat. Kodak Black)  spotify:track:1f5cbQtDrykjarZVrShaDI  A Boogie Wit da Hoodie  spotify:artist:31W5EY0aAly4Qieq6OFu6I        The Bigger Artist  spotify:album:3HHp5I6Q6SEyU5bkvoCtnV       209269
#   25053  4367  Vibes         false   1509408000         132         113              1         58            Backseat Freestyle  spotify:track:6fAyRZ0GHuuvSOEIOwi58N          Kendrick Lamar  spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg   good kid, m.A.A.d city  spotify:album:6PBZN8cbwkqm1ERj2BGXJ1       212653
#   25002  4367  Vibes         false   1509408000         132         113              1          7                          DNA.  spotify:track:6HZILIRieu8S0iqY8kIKhj          Kendrick Lamar  spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg                    DAMN.  spotify:album:4eLPsYPBmXABThSJ821sqY       185946
#   25023  4367  Vibes         false   1509408000         132         113              1         28      Litty (feat. Tory Lanez)  spotify:track:5J5PXmMdQ2nh1lZOal8KmK               Meek Mill  spotify:artist:20sxb77xiYeusSH8cVdatc                      DC4  spotify:album:6sNbRwX0lZREkdmUSDsVzo       280615
#   25074  4367  Vibes         false   1509408000         132         113              1         79       Big Shots (feat. Reezy)  spotify:track:5EDclGBSkxbRI4ClZrOTT7            Dizzy Wright  spotify:artist:1LrWZc2qPhRCHyr6XtpBxq         The Golden Age 2  spotify:album:5EpXnjGwiV8TCzmQLwfFA5       182714
#   ...     ...    ...           ...          ...         ...         ...            ...        ...                           ...                                   ...                     ...                                    ...                      ...                                   ...          ...
#   25081  4367  Vibes         false   1509408000         132         113              1         86                      G.O.M.D.  spotify:track:16qYlQ6koFxYVbiJbGHblz                 J. Cole  spotify:artist:6l3HvQ5sa6mXTsMTB19rO5  2014 Forest Hills Drive  spotify:album:7viNUmZZ8ztn2UB4XB3jIL       301133
#   25062  4367  Vibes         false   1509408000         132         113              1         67                    Shake That  spotify:track:6KqKg8IPuvtDB3PNAvffFf                  Eminem  spotify:artist:7dGJo4pcD2V6oG8kP0tJRR             Curtain Call  spotify:album:71xFWYFtiHC8eP99QB30AA       274440
#   25121  4367  Vibes         false   1509408000         132         113              1        126                 XO TOUR Llif3  spotify:track:7GX5flRQZVHRAGd6B4TmDO            Lil Uzi Vert  spotify:artist:4O15NlyKLIASxsJ0PrXPfz            Luv Is Rage 2  spotify:album:733e1ZfktLSwj96X5rsMeE       182706
#   25027  4367  Vibes         false   1509408000         132         113              1         32                          Skrt  spotify:track:5v7kaZNsnyByrSJOfO8gKq             Kodak Black  spotify:artist:46SHBwWsqBkxI7EeeBEQG7                     Skrt  spotify:album:5pgyZ32nzg48ugJS2QVVuS       224864
#   25001  4367  Vibes         false   1509408000         132         113              1          6              Mask Off - Remix  spotify:track:6dVZCbi9CYtD9LjAHXRjIG                  Future  spotify:artist:1RyvyyTE3xzB2ZywiAwp0i                   FUTURE  spotify:album:17FBoXK1NU2rvJBbzdzw0r       258426
#
#   [92 rows x 15 columns],
#   4395:         pid    name collaborative  modified_at  num_tracks  num_albums  num_followers  track_pos                                     track_name                             track_uri    artist_name                             artist_uri                                         album_name                             album_uri  duration_ms
#   27011  4395  Oldies         false   1500249600         113          99              2         64                            Everybody's Talkin'  spotify:track:3c8JemHol1XwFFruXQxjCO  Harry Nilsson  spotify:artist:3RTzAwFprBqiskp550eSJX     Midnight Cowboy: Music From The Motion Picture  spotify:album:4si97m2YFhhUxllFaZxbST       152226
#   26990  4395  Oldies         false   1500249600         113          99              2         43                                   Feeling Good  spotify:track:61S0mEfdRtJ62Fc7fPqx0U    Nina Simone  spotify:artist:7G1GBhoKtEPnP86X2PvEYO                               I Put A Spell On You  spotify:album:13jolTb1DQl8IVPczYtQJ3       174000
#   26966  4395  Oldies         false   1500249600         113          99              2         19       I Want You (She's So Heavy) - Remastered  spotify:track:3Z25k4ZF6QENy2d9YatsM5    The Beatles  spotify:artist:3WrFJ7ztbogyGnTHbHJFl2                                         Abbey Road  spotify:album:0ETFjACtuP2ADo6LFhL6HN       467320
#   26972  4395  Oldies         false   1500249600         113          99              2         25                A Hard Day's Night - Remastered  spotify:track:69d54YOS8TOQiUYjX57XeA    The Beatles  spotify:artist:3WrFJ7ztbogyGnTHbHJFl2                                 A Hard Day's Night  spotify:album:71Mwd9tntFQYUk4k2DwA0D       154200
# ...
#   68010  4998  poop         false   1497398400         150         135              6         79                                            My Type  spotify:track:7rqyZM53JpYj86avtfmyeg                         Saint Motel  spotify:artist:1dWEYMPtNmvSVaDNLgB6NV                                            My Type  spotify:album:44W9VWwamOCncBJtzbMUkk       206393
#   68072  4998  poop         false   1497398400         150         135              6        141                                               Home  spotify:track:7w5cxTEzp1rfV3KCy0Bd5N  Edward Sharpe & The Magnetic Zeros  spotify:artist:7giUHu5pv6YTZgSkxxCcgh                                      Up from Below  spotify:album:39xrkt8RILtwa9DMyLkv32       303200
#   67987  4998  poop         false   1497398400         150         135              6         56                                       Swing, Swing  spotify:track:4jVhSbMMHctghoOTFuLPB2            The All-American Rejects  spotify:artist:3vAaWhdBR38Q02ohXqaNHT                           The All-American Rejects  spotify:album:6sPphURA5x4AkQXudmstAi       233266
#   68021  4998  poop         false   1497398400         150         135              6         90                                   You Wanted A Hit  spotify:track:3fU0407Cls1hLW1ap5w2Lr                     LCD Soundsystem  spotify:artist:066X20Nz7iquqkkCW6Jxy6                                  This Is Happening  spotify:album:4hnqM0JK4CM1phwfq1Ldyz       546413
#   68076  4998  poop         false   1497398400         150         135              6        145                                          It's Real  spotify:track:1K9YlxsaqEDqTaGHOdPVRJ                         Real Estate  spotify:artist:41SQP16hv1TioVYqdckmxT                                               Days  spotify:album:4F6yLWrwSlHv5aZYZ3waAb       168493
#   68078  4998  poop         false   1497398400         150         135              6        147                                      Sweetest Kill  spotify:track:412h3blgWJwtbU2TRYkbTx                 Broken Social Scene  spotify:artist:7lOJ7WXyopaxri0dbOiZkd                            Forgiveness Rock Record  spotify:album:2LHfGLiEaV595PIYmCPMmh       309306
#   67972  4998  poop         false   1497398400         150         135              6         41                                         By The Way  spotify:track:1f2V8U1BiWaC9aJWmpOARe               Red Hot Chili Peppers  spotify:artist:0L8ExT028jH3ddEcZwqJJ5                                         By The Way  spotify:album:6deiaArbeoqp1xPEGdEKp1       216933
#   67966  4998  poop         false   1497398400         150         135              6         35                                        Happy Idiot  spotify:track:5De1egu9jjq7NuMBDKySpm                     TV On The Radio  spotify:artist:3HJIB8sYPyxrFGuwvKXSLR                                              Seeds  spotify:album:093xy0P5h7elpQQMiNyQuD       183002
#   68016  4998  poop         false   1497398400         150         135              6         85                                     Beware The Dog  spotify:track:3KIIwkf6lNwJqLcx6GUIzr                       The Griswolds  spotify:artist:3nUbzTTtP2w4HqvT5y5vkV                                      Be Impressive  spotify:album:56KHvy42cumf0i7o00DTQM       201466
#   68035  4998  poop         false   1497398400         150         135              6        104                                       Only Shallow  spotify:track:52UcjsM15hjCQAUbTW2hy1                 My Bloody Valentine  spotify:artist:3G3Gdm0ZRAOxLrbyjfhii5                                           Loveless  spotify:album:3GH4IiI6jQAIvnHVdb5FB6       257519
#   68068  4998  poop         false   1497398400         150         135              6        137                               For the Damaged Coda  spotify:track:7jA5OcunWRSYXq98puhAX8                      Blonde Redhead  spotify:artist:5isqImG0rLfAgBJSPMEVXF                   Melody of Certain Damaged Lemons  spotify:album:5ozMQsDFl6QNqB2bGiMuHU       157000
#   68029  4998  poop         false   1497398400         150         135              6         98                                            Morning  spotify:track:3arVrdpOPMgLZOztBr2jM6                                Beck  spotify:artist:3vbKDsSS70ZX9D2OcvbZmS                                      Morning Phase  spotify:album:3BBFUxPg8KFmAv96SmY4ok       319786
#   68022  4998  poop         false   1497398400         150         135              6         91  Rock & Roll - 2015 Remastered Full Length Version  spotify:track:1o6DclZHw0HomxXEQR1ijX              The Velvet Underground  spotify:artist:1nJvji2KIlWSseXRSlNYsC         Loaded: Re-Loaded 45th Anniversary Edition  spotify:album:2ny1rPsLOoKNFZhMLubMrs       283000
#   68041  4998  poop         false   1497398400         150         135              6        110                                      Pacific Theme  spotify:track:03gKdAQAswBo7v4p8F1An4                 Broken Social Scene  spotify:artist:7lOJ7WXyopaxri0dbOiZkd                            You Forgot It In People  spotify:album:6nL0U84JsEJ0cRsGCnsDnJ       309186
#   68074  4998  poop         false   1497398400         150         135              6        143                                           My Girls  spotify:track:7jZBPuJmkOsfPkwFD30dAA                   Animal Collective  spotify:artist:4kwxTgCKMipBKhSnEstNKj                         Merriweather Post Pavilion  spotify:album:6BRq5g6CWiFgN3NrjLGAYq       340786
#   67957  4998  poop         false   1497398400         150         135              6         26                                            Madness  spotify:track:0c4IEciLCDdXEhhKxj4ThA                                Muse  spotify:artist:12Chz98pHFMPJEknJQMWvI                                        The 2nd Law  spotify:album:3KuXEGcqLcnEYWnn3OEGy0       281040
#   67945  4998  poop         false   1497398400         150         135              6         14                                  Undercover Martyn  spotify:track:2jnvdMCTvtdVCci3YLqxGY                Two Door Cinema Club  spotify:artist:536BYVgOnRky0xjsPT96zl                                    Tourist History  spotify:album:0gyRFAfY08NFv7N8RTFg9M       167773
#   68011  4998  poop         false   1497398400         150         135              6         80                                     American Money  spotify:track:4AewKenHXKBt643p473xCk                               BØRNS  spotify:artist:1KP6TWI40m7p3QBTU6u2xo                                           Dopamine  spotify:album:17l7MIu0Jh0tdgK7or9ovw       260986
#   68020  4998  poop         false   1497398400         150         135              6         89                                      What You Know  spotify:track:6jrMVRReY24qzCfe1BRrww                Two Door Cinema Club  spotify:artist:536BYVgOnRky0xjsPT96zl                                    Tourist History  spotify:album:0gyRFAfY08NFv7N8RTFg9M       191400
#   68040  4998  poop         false   1497398400         150         135              6        109                                    7/4 (Shoreline)  spotify:track:4K3d2N6TYAhrOg6xTsyCVx                 Broken Social Scene  spotify:artist:7lOJ7WXyopaxri0dbOiZkd                                Broken Social Scene  spotify:album:0leOdgkByutK2TytdK0cxu       293866
#   67937  4998  poop         false   1497398400         150         135              6          6                                           Reptilia  spotify:track:2hmibAtdObO8F4tnhLENuQ                         The Strokes  spotify:artist:0epOFNiUfyON9EYx7Tpr6V                                       Room On Fire  spotify:album:5OA9iN6WTzunqAdiuEpr7Q       219826
#   68046  4998  poop         false   1497398400         150         135              6        115                                          Idioteque  spotify:track:7xqeIdLJSf3bgmZ7vUvHrE                           Radiohead  spotify:artist:4Z8W4fKeB5YxbusRsdQVPb                                              Kid A  spotify:album:19RUXBFyM4PpmrLRdtqWbp       309093
#   68017  4998  poop         false   1497398400         150         135              6         86                                      San Francisco  spotify:track:2eQOMQkStoRUQyq6HGh1iG                        The Mowgli's  spotify:artist:6AGUQK1EWK6nvN4pLIDQDQ                               Waiting For The Dawn  spotify:album:4pmOIOmY4QXH1rMSqHMOGH       173093
#   67955  4998  poop         false   1497398400         150         135              6         24                                         Inside Out  spotify:track:7qCZgvV98j6RjUULW1s1it                               Spoon  spotify:artist:0K1q0nXQ8is36PzOKAMbNe                                  They Want My Soul  spotify:album:55TZx6GWm1hlEbRgkGRjma       301960
#   68054  4998  poop         false   1497398400         150         135              6        123                                              Shout  spotify:track:5TXAySV8WBjAIMg3lPDCLN                     Tears For Fears  spotify:artist:4bthk9UfsYUYdcFyqxmSUU                           Songs From The Big Chair  spotify:album:00EZ3edHfcpcHJpRl3QcQX       392675
#   67982  4998  poop         false   1497398400         150         135              6         51                                                505  spotify:track:58ge6dfP91o9oXMzq3XkIS                      Arctic Monkeys  spotify:artist:7Ln80lUS6He07XvHI8qqHH                          Favourite Worst Nightmare  spotify:album:6rsQnwaoJHxXJRCDBPkBRw       253586
#   67953  4998  poop         false   1497398400         150         135              6         22                                    Say It Ain't So  spotify:track:4YPhn26bIFm2KUkL1VLzQG                              Weezer  spotify:artist:3jOstUTkEu2JkjvRdBA5Gu                                             Weezer  spotify:album:33CmI2lR8PnQwz6133Mc7l       256880
#   67983  4998  poop         false   1497398400         150         135              6         52                          Junk of the Heart (Happy)  spotify:track:7affvLKViJBanMz6XZhc8x                           The Kooks  spotify:artist:1GLtl8uqKmnyCWxHmw9tL4                                  Junk Of The Heart  spotify:album:0z6U8vhmrdniTrdxJkwWji       188080
#   67949  4998  poop         false   1497398400         150         135              6         18                                              Money  spotify:track:4iWuv4YvZZJZpx1D7QNLDy                           The Drums  spotify:artist:0p5axeJsbtTCXBrRVoKjwu                                         Portamento  spotify:album:1NAjWuELiyrM0RoQfNbHWb       233639
#   68012  4998  poop         false   1497398400         150         135              6         81                                            Spirits  spotify:track:2H6dHxAxGq5oQ9EiinNpXT                     The Strumbellas  spotify:artist:6ujr1NkqbZpYOhquczUUfl                                               Hope  spotify:album:6B1KctQ1VnT6JW93c5xLKF       203653
#   67935  4998  poop         false   1497398400         150         135              6          4                                I Turn My Camera On  spotify:track:5uIeRAC9O1ZXPQEEqpPVLL                               Spoon  spotify:artist:0K1q0nXQ8is36PzOKAMbNe                                      Gimme Fiction  spotify:album:47ZvaldTIhLVbVvrcysKLf       212026
#   68045  4998  poop         false   1497398400         150         135              6        114                                               1979  spotify:track:3Y8Ff1nH44jFywAtpgmleZ               The Smashing Pumpkins  spotify:artist:40Yq4vzPs9VNUrIBG5Jr2i             Mellon Collie and the Infinite Sadness  spotify:album:4bPT6Q8ppaSNppk1kbEbLl       266200
#   68034  4998  poop         false   1497398400         150         135              6        103                      A) the Wonder (Album Version)  spotify:track:38UFVZucTzkIyg26PCQLMe                         Sonic Youth  spotify:artist:5UqTO8smerMvxHYA5xsXb6                   Daydream Nation (Deluxe Edition)  spotify:album:23O4F21GDWiGd33tFN3ZgI       255826
#   67997  4998  poop         false   1497398400         150         135              6         66                                       Phantom Limb  spotify:track:2B2iC4GzVuGyPgqR8MJvET                           The Shins  spotify:artist:4LG4Bs1Gadht7TCrMytQUO                             Wincing the Night Away  spotify:album:5ByHEWLmUbRjzwC93c0WcU       287533
#   68025  4998  poop         false   1497398400         150         135              6         94                                Killing In The Name  spotify:track:59WN2psjkt1tyaxjspN8fp            Rage Against The Machine  spotify:artist:2d0hyoQ5ynDBnkvAbJKORj  Rage Against The Machine - XX (20th Anniversar...  spotify:album:4Io5vWtmV1rFj4yirKb4y4       313573
#   67967  4998  poop         false   1497398400         150         135              6         36                      Circadian Rhythm (Last Dance)  spotify:track:0zAe7oUseLPmS8EP8Yqfy2                   Silversun Pickups  spotify:artist:6qyi8X6MdP1lu6B1K6yh3h                                      Better Nature  spotify:album:02gH963ro23jvFuWkBds0s       229013
#   67948  4998  poop         false   1497398400         150         135              6         17                                      Midnight City  spotify:track:1eyzqe2QqGZUmfcPZtrIyt                                 M83  spotify:artist:63MQldklfxkjYDoUE4Tppz                           Hurry Up, We're Dreaming  spotify:album:6R0ynY7RF20ofs9GJR5TXR       241440
#   67938  4998  poop         false   1497398400         150         135              6          7                                     Chelsea Dagger  spotify:track:1bCmvezFg5MRcENzCGG1Cy                       The Fratellis  spotify:artist:3M4ThdJR28z9eSMcQHAZ5G                                     Costello Music  spotify:album:7avNT7QnpWXl1Khqnsguaw       215306
#   68018  4998  poop         false   1497398400         150         135              6         87                                Cigarette Daydreams  spotify:track:2tznHmp70DxMyr2XhWLOW0                   Cage The Elephant  spotify:artist:26T3LtbuGT1Fu9m0eRq5X3                                         Melophobia  spotify:album:4EK8gtQfdVsmDTji7gBFlz       208760
#   68008  4998  poop         false   1497398400         150         135              6         77                                            Inhaler  spotify:track:3tRqWoZuQtOfG54Vd6nNdq                               Foals  spotify:artist:6FQqZYVfTNQ1pCqfkwVFEa                                          Holy Fire  spotify:album:0PIR7PK8DMB4pgoxq7F9Ad       292546
#   67961  4998  poop         false   1497398400         150         135              6         30                                    Teenage Dirtbag  spotify:track:25FTMokYEbEWHEdss5JLZS                             Wheatus  spotify:artist:4mYFgEjpQT4IKOrjOUKyXu                                            Wheatus  spotify:album:3xmKWmqJFoXS22tePO3mgd       241666
#   67946  4998  poop         false   1497398400         150         135              6         15                                 Dance Yrself Clean  spotify:track:2cmRpmO04TLaKPzmAzySYZ                     LCD Soundsystem  spotify:artist:066X20Nz7iquqkkCW6Jxy6                                  This Is Happening  spotify:album:4hnqM0JK4CM1phwfq1Ldyz       536471
#   68042  4998  poop         false   1497398400         150         135              6        111                                          Too young  spotify:track:2THkQauDWMvJgXFGPY4iKB                             Phoenix  spotify:artist:1xU878Z1QtBldR7ru9owdU                                             United  spotify:album:5MBUL8d9FAYCCMrogOFX68       197973
#   67999  4998  poop         false   1497398400         150         135              6         68                              Don't Swallow the Cap  spotify:track:0QEHU0ZccfSXYUpF2iVUab                        The National  spotify:artist:2cCUtGK9sDU2EoElnk0GNB                               Trouble Will Find Me  spotify:album:2JhR4tjuc3MIKa8v2JaKze       285533})

# %%
train_rec = {} # a dictionary with pid as key and uri of the recommanded songs
for x in train_playlists_dict:
  train_rec[x] = recommend_songs_test(train_playlists_dict[x], 30)

# %%
#a dictionary with pid as key and r-precision
r_pre = {}
for pl in train_rec:
  score = 0
  for track, count in train_rec[pl]:
    if track in list(test_playlists_dict[pl]['track_uri']):
      score += 1
  r_pre[pl] = score/len(test_playlists_dict[pl]['track_uri'])

r_pre
# Out:
# {4003: 0.03125,
#  4129: 0.0,
#  4130: 0.0,
#  4131: 0.0,
#  4133: 0.0,
#  4138: 0.0,
#  4175: 0.03508771929824561,
#  4179: 0.0,
#  4191: 0.043478260869565216,
#  4226: 0.0,
#  4296: 0.0,
#  4367: 0.0,
#  4395: 0.0,
#  4410: 0.0,
#  4471: 0.0,
#  4516: 0.0,
#  4530: 0.0,
#  4594: 0.0,
#  4653: 0.0,
#  4751: 0.0,
#  4762: 0.0,
#  4783: 0.021739130434782608,
#  4811: 0.0,
#  4967: 0.0,
#  4998: 0.0}
